# %%
from urllib import request, error
from typing import List, Dict, Any, Iterable, Tuple, Optional
import os, json, time, hashlib, requests
from tqdm import tqdm

from pathlib import Path
import json, random, itertools, gc, statistics as st
import seqeval
import re
import requests
import time
from requests.exceptions import ReadTimeout, ConnectionError

import numpy as np
import pandas as pd
from datasets import Dataset, DatasetDict
from sklearn.model_selection import KFold, train_test_split
from collections import Counter
from sentence_transformers import SentenceTransformer
from sklearn.neighbors import BallTree
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity, pairwise_distances
from sklearn.cluster import KMeans
from IPython.display import clear_output

import torch
from transformers import (
    AutoTokenizer,
        AutoModelForTokenClassification,
    TrainingArguments,
    Trainer,


    DataCollatorForTokenClassification
)

from seqeval.metrics import classification_report, f1_score, precision_score, recall_score, accuracy_score
from seqeval.scheme import IOB2
from evaluate import load as load_metric
from tqdm.auto import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 import json, random, itertools, gc, statistics as st
#       8 import seqeval
# ----> 9 import openai
#      10 import re
#      11 import requests
#
# ModuleNotFoundError: No module named 'openai'

# %%
HOST = "http://127.0.0.1:11434"

# >>> Escolha um que REALMENTE está instalado (copie/cole da sua /api/tags):
MODEL_KEY = "llama3.1:8b"
# Alternativas que você tem: "qwen2.5:14b-instruct", "deepseek-r1:14b"

# Catálogo só para opções (não interfere no nome/tag do modelo)
OLLAMA_MODELS = {
    # --- já instalados ---
    "gemma2:9b":              {"options": {"num_ctx": 8000,  "temperature": 0.2}},
    "llama3.1:8b":            {"options": {"num_ctx": 8000,  "temperature": 0.2}},
    "qwen2.5:14b-instruct":   {"options": {"num_ctx": 12000, "temperature": 0.2}},
    "deepseek-r1:14b":        {"options": {"num_ctx": 8000,  "temperature": 0.2}},

    # --- Qwen mais leve ---
    "qwen2.5:7b":             {"options": {"num_ctx": 8000,  "temperature": 0.2}},
    "qwen2.5:7b-instruct":    {"options": {"num_ctx": 8000,  "temperature": 0.2}},  # use esta p/ chat

    # --- DeepSeek R1 mais leve ---
    "deepseek-r1:7b":         {"options": {"num_ctx": 8000,  "temperature": 0.2}},
    "deepseek-r1:1.5b":       {"options": {"num_ctx": 4096,  "temperature": 0.2}},  # ultraleve

    # --- “GPT OS” (gpt-oss open-weights) ---
    "gpt-oss:20b":            {"options": {"num_ctx": 8000,  "temperature": 0.2}},
}

# %%
SAFE_MODEL  = re.sub(r'[^A-Za-z0-9._-]+', '_', str(MODEL_KEY))  # "gemma2:9b" -> "gemma2_9b"

# --- pastas por modelo ---
BASE_DIR    = Path("caches") / SAFE_MODEL
DIR_CACHE   = BASE_DIR / "cache"
DIR_CKPT    = BASE_DIR / "checkpoints"
DIR_LOGS    = BASE_DIR / "logs"
for d in (DIR_CACHE, DIR_CKPT, DIR_LOGS):
    d.mkdir(parents=True, exist_ok=True)

# %%
CACHE_PATH  = DIR_CACHE / "ner_cache.jsonl"

# %%
OLLAMA_MODELS[MODEL_KEY]["options"].update({
    "temperature": 0.0,
    "repeat_penalty": 1.1,
})

# %%
JSON_PATH = "../data/geocorpus-v2.json"        # ajuste se estiver noutra pasta
SEED_GLOBAL = 42
FEW_SHOT_K = 20

random.seed(SEED_GLOBAL)
np.random.seed(SEED_GLOBAL)

# ---------- ler o arquivo ----------
with open(JSON_PATH, encoding="utf-8") as f:
    raw = json.load(f)

# %%
records_geo = [
    {
        "sentence_id": i,
        "tokens"     : item["tokens"],
        "ner_tags"   : item["ner_tokens"],
    }
    for i, item in enumerate(raw)
]

geocorpus_full = Dataset.from_list(records_geo)

# %%
# lista de rótulos (ordem alfabética garante consistência entre runs)
label_list = sorted({l for sent in geocorpus_full["ner_tags"] for l in sent})
label2id   = {l: i for i, l in enumerate(label_list)}
id2label   = {i: l for l, i in label2id.items()}
NUM_LABELS = len(label_list)

# %%
iob_labels = (
    "O "
    "B-baciaSedimentar I-baciaSedimentar "
    "B-epoca I-epoca "
    "B-idade I-idade "
    "B-periodo I-periodo "
    "B-eon I-eon "
    "B-era I-era "
    "B-magmaticas I-magmaticas "
    "B-metamorficas I-metamorficas "
    "B-sedimentaresSiliciclasticas I-sedimentaresSiliciclasticas "
    "B-sedimentaresCarbonaticas I-sedimentaresCarbonaticas "
    "B-unidadeEstratigrafica I-unidadeEstratigrafica "
    "B-contextoGeologicoDeBacia I-contextoGeologicoDeBacia "
    "B-ambienteSedimentacao I-ambienteSedimentacao "
    "B-constituinteRochaSedimentar I-constituinteRochaSedimentar "
    "B-fosseis I-fosseis "
    "B-planctonico I-planctonico "
    "B-bentonico I-bentonico "
    "B-mineral I-mineral "
    "B-procedimentoMetodologico I-procedimentoMetodologico"
)

# %% [markdown]
# # Splits

# %%
def random_splits(
    ds: Dataset, test_size=0.2, seeds: List[int] = range(30)
) -> List[DatasetDict]:
    triples = []
    for s in seeds:
        train, dev = ds.train_test_split(test_size=test_size, seed=s).values()
        triples.append(DatasetDict(train=train, dev=dev))
    return triples

# %%
# def split_heur_length(ds: Dataset, top_pct: float = 0.20) -> DatasetDict:
#     lengths = np.array([len(t) for t in ds["tokens"]])
#     thr = np.percentile(lengths, 100 * (1 - top_pct))
#     mask = lengths >= thr
#     return DatasetDict(train=ds.filter(~mask), dev=ds.filter(mask))


def split_heur_length(ds: Dataset, top_pct: float = 0.20) -> DatasetDict:
    """20 % das sentenças mais longas viram conjunto de validação (dev)."""
    lengths = np.array([len(t) for t in ds["tokens"]])
    thr = np.percentile(lengths, 100 * (1 - top_pct))  
    mask = lengths >= thr  

    dev_idx = np.where(mask)[0].tolist()  # índices → list[int]
    train_idx = np.where(~mask)[0].tolist()

    return DatasetDict(
        train=ds.select(train_idx),
        dev=ds.select(dev_idx),
    )

    # Tamanho da sentenças


# def split_heur_rare(ds: Dataset, freq_thr: int = 5) -> DatasetDict:
#     freq = Counter(w.lower() for sent in ds["tokens"] for w in sent)
#     rare = {w for w, c in freq.items() if c <= freq_thr}

#     def has_rare(example):
#         return any(w.lower() in rare for w in example["tokens"])

#     return DatasetDict(
#         train=ds.filter(lambda ex: not has_rare(ex)), dev=ds.filter(has_rare)
#     )


def split_heur_rare(ds: Dataset, freq_thr: int = 5) -> DatasetDict:
    freq = Counter(w.lower() for sent in ds["tokens"] for w in sent)
    rare = {w for w, c in freq.items() if c <= freq_thr}

    keep_dev = []
    for sent in ds["tokens"]:
        print(sent)
        keep_dev.append(any(w.lower() in rare for w in sent))

    dev_idx = [i for i, x in enumerate(keep_dev) if x]
    train_idx = [i for i, x in enumerate(keep_dev) if not x]

    return DatasetDict(
        train=ds.select(train_idx),
        dev=ds.select(dev_idx),
    )

    # Raridade dos tokens

# %%
def split_adversarial(ds: Dataset, pct_test: float = 0.20) -> DatasetDict:
    k = int(len(ds) * pct_test)
    model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
    embeds = model.encode([" ".join(t) for t in ds["tokens"]], show_progress_bar=False)
    tree = BallTree(embeds, leaf_size=40)

    idx_train, idx_test = set(range(len(ds))), []
    # semente = ponto mais central
    seed_idx = np.argmax(np.linalg.norm(embeds - embeds.mean(0), axis=1))
    idx_train.remove(seed_idx)
    idx_test.append(seed_idx)
    print(k)
    while len(idx_test) < k:
        print(len(idx_test))
        dists, _ = tree.query(embeds[list(idx_train)], k=1, return_distance=True)
        nxt = list(idx_train)[int(np.argmax(dists))]
        idx_train.remove(nxt)
        idx_test.append(nxt)

    return DatasetDict(
        train=ds.select(sorted(idx_train)),
        dev=ds.select(sorted(idx_test)),
    )

    # Maximizando Wassertein Distance


def split_adversarial_fast(ds: Dataset, pct_test: float = 0.20) -> DatasetDict:
    """
    Farthest-Point Sampling aproximando Wasserstein – versão vetorizada.
    Seleciona pct_test (~20 %) das sentenças como conjunto 'dev'.
    """
    k = int(len(ds) * pct_test)
    model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

    embeds = model.encode(
        [" ".join(t) for t in ds["tokens"]],
        show_progress_bar=True,
        convert_to_numpy=True,
        normalize_embeddings=True,  # acelera distância euclidiana ≈ cos
    )

    n = embeds.shape[0]
    idx_all = np.arange(n)

    # 1) ponto mais "central" (norma mais distante da média)
    seed_idx = np.argmax(np.linalg.norm(embeds - embeds.mean(0), axis=1))
    selected = [seed_idx]

    # 2) vetor de distâncias mínimas a qualquer ponto já escolhido
    min_dists = np.linalg.norm(embeds - embeds[seed_idx], axis=1)

    while len(selected) < k:
        next_idx = np.argmax(min_dists)
        selected.append(next_idx)

        # atualiza min_dists com a distância ao novo ponto — tudo de uma vez
        d_new = np.linalg.norm(embeds - embeds[next_idx], axis=1)
        min_dists = np.minimum(min_dists, d_new)

    train_idx = np.setdiff1d(idx_all, selected, assume_unique=True)

    return DatasetDict(
        train=ds.select(train_idx.tolist()),
        dev=ds.select(selected),
    )

# %%
# def loc_split(
#     dataset: Dataset, pct_test: float = 0.20, ngram: int = 4, seed: int = 42
# ) -> DatasetDict:
#     """
#     Split baseado em baixa sobreposição léxica (4-gram Jaccard).
#     Teste = pct_test das sentenças com menor overlap em relação ao pool.
#     """
#     # 1. Texto plano por sentença
#     docs = [" ".join(toks) for toks in dataset["tokens"]]

#     # 2. Vetorizar 4-grams (binário)
#     vect = CountVectorizer(
#         analyzer="word", ngram_range=(ngram, ngram), binary=True
#     ).fit(docs)
#     X = vect.transform(docs)

#     # 3. Similaridade Jaccard aproximada com matriz binária
#     # Jaccard(A,B) = |A∩B|/|A∪B| = 1 - |AΔB|/|A∪B|
#     # Usamos: overlap = (A·Bᵀ) / (|A|+|B|-A·Bᵀ)
#     bin_counts = X.sum(axis=1).A1

#     # Para cada doc i, escolhemos vizinho + próximo (fast):
#     from sklearn.metrics.pairwise import cosine_similarity

#     # (cosine no binário ∝ |A∩B|)
#     sim = cosine_similarity(X, dense_output=False)
#     # Soma dos top-k overlaps (k=5) como score
#     k = 5
#     topk = np.zeros(len(dataset))
#     for i in range(sim.shape[0]):
#         row = sim.getrow(i).toarray()[0]
#         idx = np.argpartition(-row, range(1, k + 1))[1 : k + 1]
#         # overlap ≈ |∩|
#         inter = row[idx] * bin_counts[i]
#         uni = bin_counts[i] + bin_counts[idx] - inter
#         topk[i] = (inter / uni).mean()

#     # 4. Ordenar por overlap crescente ⇒ mais “novos” vão p/ teste
#     order = np.argsort(topk)
#     n_test = int(len(dataset) * pct_test)
#     test_idx = order[:n_test]
#     train_idx = order[n_test:]

#     return DatasetDict(
#         {"train": dataset.select(train_idx), "test": dataset.select(test_idx)}
#     )

# %%
def loc_split(
    dataset: Dataset,
    pct_test: float = 0.20,
    pct_val: float = 0.10,
    ngram: int = 4,
    seed: int = 42,
) -> DatasetDict:
    """
    Divide por sobreposição léxica (n-gram Jaccard).
    Frações independentes para teste e validação.
    """
    docs = [" ".join(toks) for toks in dataset["tokens"]]

    vect = CountVectorizer(
        analyzer="word", ngram_range=(ngram, ngram), binary=True
    ).fit(docs)
    X = vect.transform(docs)
    bin_counts = X.sum(axis=1).A1

    sim = cosine_similarity(X, dense_output=False)
    k = 5
    topk = np.zeros(len(dataset))
    for i in range(sim.shape[0]):
        row = sim.getrow(i).toarray()[0]
        idx = np.argpartition(-row, range(1, k + 1))[1 : k + 1]
        inter = row[idx] * bin_counts[i]
        uni = bin_counts[i] + bin_counts[idx] - inter
        topk[i] = (inter / uni).mean()

    order = np.argsort(topk)  # baixo → alto overlap
    n_test = int(len(dataset) * pct_test)
    n_val = int(len(dataset) * pct_val)

    test_idx = order[:n_test]
    val_idx = order[n_test : n_test + n_val]
    train_idx = order[n_test + n_val :]

    return DatasetDict(
        {
            "train": dataset.select(train_idx),
            "val": dataset.select(val_idx),
            "test": dataset.select(test_idx),
        }
    )

# %%
def semantic_cluster_split(
    dataset: Dataset,
    pct_test: float = 0.20,
    pct_val: float = 0.10,
    k: int | None = None,
    seed: int = 42,
) -> DatasetDict:
    """
    Clusters SBERT → reserva clusters distantes para test/val.
    """
    if k is None:
        k = int(np.sqrt(len(dataset)))

    sbert = SentenceTransformer(
        "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
    )
    embeddings = sbert.encode(
        [" ".join(t) for t in tqdm(dataset["tokens"])],
        batch_size=64,
        show_progress_bar=False,
    )

    km = KMeans(n_clusters=k, random_state=seed, n_init=10).fit(embeddings)
    labels = km.labels_
    centroids = km.cluster_centers_

    global_center = embeddings.mean(0, keepdims=True)
    dists = pairwise_distances(centroids, global_center).flatten()

    clusters_sorted = np.argsort(-dists)  # mais distantes primeiro
    test_clusters, val_clusters = set(), set()
    total_test = total_val = 0
    n_test = int(len(dataset) * pct_test)
    n_val = int(len(dataset) * pct_val)

    for c in clusters_sorted:
        size = np.sum(labels == c)
        if total_test < n_test:  # preenche primeiro o teste
            test_clusters.add(c)
            total_test += size
        elif total_val < n_val:  # depois a validação
            val_clusters.add(c)
            total_val += size
        if total_test >= n_test and total_val >= n_val:
            break

    test_idx = np.where([lbl in test_clusters for lbl in labels])[0]
    val_idx = np.where([lbl in val_clusters for lbl in labels])[0]
    train_idx = np.where(
        [lbl not in test_clusters and lbl not in val_clusters for lbl in labels]
    )[0]

    return DatasetDict(
        {
            "train": dataset.select(train_idx),
            "val": dataset.select(val_idx),
            "test": dataset.select(test_idx),
        }
    )

# %%
def difficulty_scores(dataset: Dataset) -> np.ndarray:
    length = np.array([len(tok) for tok in dataset["tokens"]], dtype=float)
    length = (length - length.mean()) / length.std()

    dens = []
    for labels in dataset["ner_tags"]:
        non_o = sum(1 for l in labels if l != "O")
        dens.append(non_o / len(labels))
    dens = np.array(dens)
    dens = (dens - dens.mean()) / dens.std()

    ent_types, freq = [], Counter()
    for labels in dataset["ner_tags"]:
        types = [l[2:] for l in labels if l != "O"]
        ent_types.append(types[0] if types else "NONE")
    freq.update(ent_types)
    rarity = np.array([1 / freq[t] for t in ent_types])
    rarity = (rarity - rarity.mean()) / rarity.std()

    return length + dens + rarity


def reverse_curriculum_split(
    dataset: Dataset, pct_test: float = 0.20, pct_val: float = 0.10, seed: int = 42
) -> DatasetDict:
    scores = difficulty_scores(dataset)
    order = np.argsort(scores)  # easy→hard
    n_test = int(len(dataset) * pct_test)
    n_val = int(len(dataset) * pct_val)

    test_idx = order[-n_test:]  # hardest
    val_idx = order[-(n_test + n_val) : -n_test]
    train_idx = order[: -(n_test + n_val)]

    rng = np.random.RandomState(seed)
    rng.shuffle(train_idx)
    rng.shuffle(val_idx)
    rng.shuffle(test_idx)

    return DatasetDict(
        {
            "train": dataset.select(train_idx),
            "val": dataset.select(val_idx),
            "test": dataset.select(test_idx),
        }
    )

# %%
def heur_len_split(dataset: Dataset,
                   pct_test: float = 0.20,
                   pct_val : float = 0.10,
                   seed: int = 42) -> DatasetDict:
    """Testa só sentenças ≥ máx(len_train)."""
    sent_lens = np.array([len(t) for t in dataset["tokens"]])
    # separação inicial train/dev (randômica estratificando por tamanho grosso)
    idx_all   = np.arange(len(dataset))
    train_idx, temp_idx = train_test_split(idx_all,
                                           test_size=pct_test + pct_val,
                                           stratify=(sent_lens//5),  # bin len
                                           random_state=seed)
    # define longo-threshold como tamanho máx. do treino
    max_train_len = sent_lens[train_idx].max()
    # test = sentenças > threshold.  Caso falte/ sobre exemplos, ajusta.
    test_idx  = [i for i in temp_idx if sent_lens[i] > max_train_len]
    resto_idx = [i for i in temp_idx if i not in test_idx]
    # completa ou reduz para atingir pct_test
    need = int(pct_test*len(dataset)) - len(test_idx)
    if need > 0:
        test_idx.extend(resto_idx[:need])
        val_idx = resto_idx[need:]
    else:
        val_keep = int(pct_val*len(dataset))
        val_idx  = resto_idx[:val_keep]
        test_idx = test_idx[: int(pct_test*len(dataset))]
    return DatasetDict({
        "train": dataset.select(train_idx),
        "val"  : dataset.select(val_idx),
        "test" : dataset.select(test_idx),
    })

# ---------- 2) Heuristic Rare-Words ----------------------------------
def heur_rare_split(dataset: Dataset,
                    pct_test: float = 0.20,
                    pct_val : float = 0.10,
                    seed: int = 42) -> DatasetDict:
    """Testa frases que contenham palavras do quintil + raro."""
    # contagem de frequência de token
    freqs = Counter(w for toks in dataset["tokens"] for w in toks)
    # define rareza: 20 % mais raras
    thresh = np.quantile(list(freqs.values()), 0.20)
    rare_set = {w for w,c in freqs.items() if c <= thresh}
    is_rare = np.array([any(w in rare_set for w in toks)
                        for toks in dataset["tokens"]])
    rare_idx   = np.where(is_rare)[0]
    common_idx = np.where(~is_rare)[0]
    # garante proporções desejadas
    n_test = int(pct_test*len(dataset))
    n_val  = int(pct_val *len(dataset))
    rng = np.random.default_rng(seed)
    test_idx = rng.choice(rare_idx, size=min(len(rare_idx), n_test),
                          replace=False)
    resto_idx = [i for i in rare_idx if i not in test_idx] + list(common_idx)
    val_idx  = rng.choice(resto_idx, size=n_val, replace=False)
    train_idx = [i for i in resto_idx if i not in val_idx]
    return DatasetDict({
        "train": dataset.select(train_idx),
        "val"  : dataset.select(val_idx),
        "test" : dataset.select(test_idx),
    })

# ---------- 3) Standard (80-10-10) -----------------------------------
def std_split(dataset: Dataset,
              pct_test: float = 0.10,
              pct_val : float = 0.10,
              seed: int = 42) -> DatasetDict:
    """Split aleatório estratificado por comprimento (PTB-like)."""
    idx = np.arange(len(dataset))
    strat = (np.array([len(t) for t in dataset["tokens"]]) // 5)
    train_idx, temp_idx = train_test_split(idx, test_size=pct_test+pct_val,
                                          stratify=strat, random_state=seed)
    val_rel = pct_val / (pct_test+pct_val)
    val_idx, test_idx = train_test_split(temp_idx, test_size=1-val_rel,
                                         stratify=strat[temp_idx],
                                         random_state=seed)
    return DatasetDict({
        "train": dataset.select(train_idx),
        "val"  : dataset.select(val_idx),
        "test" : dataset.select(test_idx),
    })

# ---------- 4) Adversarial (approx. Wasserstein) ---------------------
def adversarial_split(dataset: Dataset,
                      pct_test: float = 0.20,
                      pct_val : float = 0.10,
                      k: int = 5,
                      seed: int = 42) -> DatasetDict:
    """
    Seleciona k frases 'mais distantes' recursivamente (BallTree + W₂)
    para compor o teste, lembrando Alg.-1 de Søgaard et al.【turn6file4】.
    """
    # SBERT embed (rápido na GPU / aceitável CPU)
    sbert = SentenceTransformer(
        "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
    )
    emb = sbert.encode([" ".join(toks) for toks in dataset["tokens"]],
                       batch_size=64, show_progress_bar=False)
    # BallTree para vizinhança eficiente
    tree = BallTree(emb, leaf_size=40)
    idx_pool = set(range(len(dataset)))
    test_idx = []
    rng = np.random.default_rng(seed)
    while len(test_idx) < int(pct_test*len(dataset)):
        # amostra candidata: ponto + longe do centro
        center = emb[list(idx_pool)].mean(0, keepdims=True)
        dists, _ = tree.query(center, k=len(idx_pool))
        farthest = list(idx_pool)[int(dists.argmax())]
        # pega-se farest e seus k-NN mais próximos  ⇒ aumenta diversidade
        nn = tree.query([emb[farthest]], k=k, return_distance=False)[0]
        for j in nn:
            if j in idx_pool and len(test_idx) < int(pct_test*len(dataset)):
                test_idx.append(j)
                idx_pool.remove(j)
    # retira val
    val_size = int(pct_val*len(dataset))
    val_idx  = rng.choice(list(idx_pool), size=val_size, replace=False)
    idx_pool -= set(val_idx)
    train_idx = list(idx_pool)
    return DatasetDict({
        "train": dataset.select(train_idx),
        "val"  : dataset.select(val_idx),
        "test" : dataset.select(test_idx),
    })

# %%
def heur_len_split(dataset: Dataset,
                   pct_test: float = 0.20,
                   pct_val : float = 0.10,
                   seed: int = 42,
                   bin_size: int = 10) -> DatasetDict:
    """
    Teste = sentenças mais longas que max(len(train)).
    Robusto a datasets pequenos: se estratificação falhar, usa split aleatório.
    """
    rng = np.random.default_rng(seed)
    idx_all   = np.arange(len(dataset))
    sent_lens = np.array([len(t) for t in dataset["tokens"]])

    # ------ 1) tenta split estratificado por baldes -------------------------
    strat = (sent_lens // bin_size)
    try:
        train_idx, temp_idx = train_test_split(
            idx_all,
            test_size=pct_test + pct_val,
            stratify=strat,
            random_state=seed,
        )
    except ValueError:                       # classes com 1 amostra
        train_idx, temp_idx = train_test_split(
            idx_all,
            test_size=pct_test + pct_val,
            shuffle=True,
            random_state=seed,
            stratify=None,
        )

    # ------ 2) escolhe test = len > max(train) ------------------------------
    max_train_len = sent_lens[train_idx].max()
    test_idx  = [i for i in temp_idx if sent_lens[i] > max_train_len]
    resto_idx = [i for i in temp_idx if i not in test_idx]

    # garante tamanhos exatos
    n_test_desired = int(pct_test * len(dataset))
    n_val_desired  = int(pct_val  * len(dataset))

    # completa teste se ficou pequeno
    if len(test_idx) < n_test_desired:
        extra = rng.choice(resto_idx,
                           size=n_test_desired - len(test_idx),
                           replace=False)
        test_idx.extend(extra)
        resto_idx = [i for i in resto_idx if i not in extra]

    # define validação
    val_idx  = rng.choice(resto_idx, size=n_val_desired, replace=False)
    train_idx = [i for i in idx_all if i not in test_idx and i not in val_idx]

    return DatasetDict({
        "train": dataset.select(train_idx),
        "val"  : dataset.select(val_idx),
        "test" : dataset.select(test_idx),
    })

# %%
def std_split(dataset,
              pct_test: float = 0.10,
              pct_val : float = 0.10,
              seed: int = 42,
              bin_size: int = 5) -> DatasetDict:
    """
    Split 80-10-10 robusto.
      • Tenta estratificar por comprimento // bin_size.
      • Se houver classes com <2 amostras, recua p/ split aleatório.
    """
    idx  = np.arange(len(dataset))
    bins = (np.array([len(t) for t in dataset["tokens"]]) // bin_size)

    try:
        train_idx, temp_idx = train_test_split(
            idx,
            test_size=pct_test + pct_val,
            stratify=bins,
            random_state=seed,
        )
    except ValueError:                       # classes muito pequenas
        train_idx, temp_idx = train_test_split(
            idx,
            test_size=pct_test + pct_val,
            shuffle=True,
            random_state=seed,
            stratify=None,
        )

    # fraciona temp em val / test mantendo proporção desejada
    val_share = pct_val / (pct_test + pct_val)
    try:
        val_idx, test_idx = train_test_split(
            temp_idx,
            test_size=1 - val_share,
            stratify=bins[temp_idx],
            random_state=seed,
        )
    except ValueError:
        val_idx, test_idx = train_test_split(
            temp_idx,
            test_size=1 - val_share,
            shuffle=True,
            random_state=seed,
            stratify=None,
        )

    return DatasetDict({
        "train": dataset.select(train_idx),
        "val"  : dataset.select(val_idx),
        "test" : dataset.select(test_idx),
    })

# %%
def adversarial_split(dataset: Dataset,
                      pct_test: float = 0.20,
                      pct_val : float = 0.10,
                      k: int = 5,
                      seed: int = 42) -> DatasetDict:
    """
    Versão robusta: nunca “trava” antes de atingir n_test.
    Seleciona blocos de k sentenças mais distantes do centro iterativamente.
    """
    # -------------------------------- embeds -------------------------------
    sbert = SentenceTransformer(
        "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
    )
    emb = sbert.encode([" ".join(t) for t in dataset["tokens"]],
                       batch_size=64, show_progress_bar=False)
    tree = BallTree(emb, leaf_size=40)

    n_test = int(pct_test * len(dataset))
    n_val  = int(pct_val  * len(dataset))

    idx_pool = set(range(len(dataset)))
    test_idx = []
    rng = np.random.default_rng(seed)

    print(f"Selecionando {n_test} sentenças para teste…")
    step = 0
    while len(test_idx) < n_test and idx_pool:
        if step % 5 == 0:
            print(f"  {len(test_idx)} selecionadas…")
        step += 1

        pool_list = list(idx_pool)
        center = emb[pool_list].mean(0, keepdims=True)

        # distância euclidiana ao centro global restante
        dists, _ = tree.query(center, k=len(pool_list))
        farthest_local_idx = int(dists.argmax())
        farthest_global_idx = pool_list[farthest_local_idx]

        # número efetivo de vizinhos
        k_eff = min(k, len(idx_pool))
        nn = set(tree.query([emb[farthest_global_idx]],
                            k=k_eff,
                            return_distance=False)[0])

        # adiciona vizinhos ainda não selecionados
        for j in nn:
            if j in idx_pool and len(test_idx) < n_test:
                test_idx.append(j)
                idx_pool.remove(j)

        # Se nada foi adicionado (pode acontecer quando sobram <k únicos)
        if farthest_global_idx not in test_idx:
            test_idx.append(farthest_global_idx)
            idx_pool.remove(farthest_global_idx)

    # ------------------------ validação e treino ---------------------------
    val_idx = rng.choice(list(idx_pool), size=n_val, replace=False)
    idx_pool -= set(val_idx)
    train_idx = list(idx_pool)

    return DatasetDict({
        "train": dataset.select(train_idx),
        "val"  : dataset.select(val_idx),
        "test" : dataset.select(test_idx),
    })

# %%
standard_split = std_split(geocorpus_full)
print('std')
# random_splt = random_splits(geocorpus_full)
# print('random')
heur_len = heur_len_split(geocorpus_full)
print("heur_len")
heur_rare = heur_rare_split(geocorpus_full)
print("heur_rare")
advers = adversarial_split(geocorpus_full)
print("advs")
loc = loc_split(geocorpus_full)
print("loc")
semantic = semantic_cluster_split(geocorpus_full)
print("semantic")
reverse = reverse_curriculum_split(geocorpus_full)
print("reverse")
# Out:
# std
# heur_len
# heur_rare
# Selecionando 1054 sentenças para teste…
#   0 selecionadas…
#   24 selecionadas…
#   47 selecionadas…
#   71 selecionadas…
#   96 selecionadas…
#   121 selecionadas…
#   144 selecionadas…
#   165 selecionadas…
#   187 selecionadas…
#   211 selecionadas…
#   232 selecionadas…
#   251 selecionadas…
#   271 selecionadas…
#   288 selecionadas…
#   305 selecionadas…
#   329 selecionadas…
#   349 selecionadas…
#   364 selecionadas…
#   383 selecionadas…
#   399 selecionadas…
#   417 selecionadas…
#   433 selecionadas…
#   452 selecionadas…
#   470 selecionadas…
#   488 selecionadas…
#   501 selecionadas…
#   515 selecionadas…
#   529 selecionadas…
#   542 selecionadas…
#   554 selecionadas…
#   565 selecionadas…
#   577 selecionadas…
#   590 selecionadas…
#   597 selecionadas…
#   610 selecionadas…
#   628 selecionadas…
#   642 selecionadas…
#   658 selecionadas…
#   671 selecionadas…
#   685 selecionadas…
#   698 selecionadas…
#   713 selecionadas…
#   724 selecionadas…
#   738 selecionadas…
#   754 selecionadas…
#   771 selecionadas…
#   785 selecionadas…
#   798 selecionadas…
#   817 selecionadas…
#   830 selecionadas…
#   844 selecionadas…
#   856 selecionadas…
#   868 selecionadas…
#   884 selecionadas…
#   894 selecionadas…
#   901 selecionadas…
#   916 selecionadas…
#   936 selecionadas…
#   951 selecionadas…
#   963 selecionadas…
#   976 selecionadas…
#   986 selecionadas…
#   998 selecionadas…
#   1015 selecionadas…
#   1032 selecionadas…
#   1047 selecionadas…
# advs
# loc
# 100%|██████████| 5272/5272 [00:00<00:00, 1355422.99it/s]
# semantic
# reverse

# %% [markdown]
# # Pipeline Ollama

# %%
def _hash_key(tokens, model, shot_id="v1"):
    # Evita recomputar exemplos iguais (inclusive entre splits)
    s = json.dumps(tokens, ensure_ascii=False)
    return hashlib.md5(f"{model}|{shot_id}|{s}".encode()).hexdigest()

# %%
def _load_cache(path):
    cache = {}
    if os.path.exists(path):
        with open(path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    rec = json.loads(line)
                    cache[rec["k"]] = rec["v"]
                except Exception:
                    pass
    return cache

# %%
def _append_cache(path, k, v):
    with open(path, "a", encoding="utf-8") as f:
        f.write(json.dumps({"k": k, "v": v}, ensure_ascii=False) + "\n")

# %%
def _normalize_ner_batch_json(obj):
    """
    Normaliza a saída do LLM para: [ {"id": int, "tags": [str, ...]}, ... ].
    Aceita variações comuns: objeto único, lista de objetos com "tokens",
    lista de listas, dict indexado por "0","1", etc.
    """
    if isinstance(obj, dict):
        if "id" in obj and ("tags" in obj or "tokens" in obj):
            tags = obj.get("tags") or obj.get("tokens")
            return [{"id": obj.get("id", 0), "tags": tags}]
        if all(isinstance(k, str) for k in obj.keys()):
            out = []
            try:
                for k in sorted(obj.keys(), key=lambda x: int(x)):
                    v = obj[k]
                    if isinstance(v, dict):
                        tags = v.get("tags") or v.get("tokens") or v.get("labels") or v
                    else:
                        tags = v
                    if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
                        out.append({"id": int(k), "tags": tags})
                    else:
                        raise ValueError("Formato não reconhecido em item indexado.")
                return out
            except Exception:
                pass
        for key in ("results", "data", "output"):
            if key in obj:
                return _normalize_ner_batch_json(obj[key])
        raise ValueError(f"Formato JSON não reconhecido (dict): {obj}")

    if isinstance(obj, list):
        if not obj:
            return []
        if isinstance(obj[0], dict):
            norm = []
            for i, rec in enumerate(obj):
                tags = rec.get("tags") if "tags" in rec else rec.get("tokens") if "tokens" in rec else rec
                rid = rec.get("id", i)
                if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
                    norm.append({"id": rid, "tags": tags})
                else:
                    if isinstance(rec, dict) and "tags" not in rec and "tokens" not in rec:
                        for key in ("tags", "tokens", "labels", "ner"):
                            if key in rec:
                                tags = rec[key]; break
                        if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
                            norm.append({"id": rid, "tags": tags})
                        else:
                            raise ValueError(f"Item da lista sem tags reconhecíveis: {rec}")
                    else:
                        raise ValueError(f"Item da lista sem tags reconhecíveis: {rec}")
            return norm
        if isinstance(obj[0], list) and all(isinstance(t, str) for t in obj[0]):
            return [{"id": i, "tags": tags} for i, tags in enumerate(obj)]
        if all(isinstance(t, str) for t in obj):
            return [{"id": 0, "tags": obj}]
        raise ValueError(f"Formato JSON não reconhecido (list): {obj}")

    raise ValueError(f"Tipo JSON não reconhecido: {type(obj).__name__}")

# %%
def chunked(iterable, n):
    it = iter(iterable)
    while True:
        chunk = list(islice(it, n))
        if not chunk:
            return
        yield chunk

# %%
def tokens_to_text(tokens: List[str]) -> str:
    # Junta preservando espaços simples.
    return " ".join(tokens)


def fmt_example(ex: dict) -> str:
    toks = ex["tokens"]
    tags = ex.get("tags") or ex.get("ner_tags")  # compatível com seus dsets
    pairs_line = " ".join(f"{i+1}-{t}" for i, t in enumerate(tags))
    return f"Tokens: {' '.join(toks)}\nSaída: {pairs_line}"

def build_prompt(few_shot: List[Dict[str, Any]], query_tokens: List[str]) -> str:
    N = len(query_tokens)
    header = f"""
        Você é um anotador especialista em NER. Rotule **cada token** usando o esquema **IOB2**.

        Regras (case-sensitive):
        1) Use apenas os rótulos:\n{iob_labels}

        2) IOB2 (cheque silenciosamente):
        • Uma entidade inicia em B-<TIPO>.
        • I-<TIPO> só após B-<TIPO> ou I-<TIPO> do mesmo TIPO.
        • Nunca iniciar com I-.

        3) Formato ÚNICO de saída (sem texto extra):
        • Uma única linha com N pares índice-rótulo (1-based), separados por espaço.
        • Cada par: <índice>-<RÓTULO>.
        • Ex.: 1-O 2-B-magmaticas 3-I-magmaticas ... N-O

        4) Se houver N tokens, produza exatamente N rótulos.
        """.strip()

    examples = "\n\n### Exemplos\n" + "\n\n".join(fmt_example(ex) for ex in few_shot)

    task = f"""
        ### Tarefa
        Tokens: {tokens_to_text(query_tokens)}

        ### Saída esperada
        Retorne **apenas**: {{"tags": ["O", "B-...", "..."]}} com {N} itens.
        """.strip()

    return f"{header}\n\n{examples}\n\n{task}"

# %%
def select_few_shot(exemplars: Dataset, k=FEW_SHOT_K) -> list[dict]:
    # amostra k exemplos aleatórios (pode trocar por stratified sampling)
    return random.sample(list(exemplars), k)

# %%
def _format_few_shot_block(few_shot):
    """
    Aceita:
      - string pronta (usa como está, cortando em ~4000 chars), ou
      - lista/iterável de exemplos com campos 'tokens' e 'ner_tags'
    Retorna um bloco curto de few-shot em texto.
    """
    if isinstance(few_shot, str):
        return few_shot.strip()[:4000]

    parts = []
    try:
        for ex in few_shot:
            toks = ex.get("tokens") if isinstance(ex, dict) else ex["tokens"]
            tags = ex.get("ner_tags") if isinstance(ex, dict) else ex["ner_tags"]
            parts.append(json.dumps({"tokens": toks, "tags": tags}, ensure_ascii=False))
    except Exception:
        # fallback: forçar string
        return str(few_shot)[:4000]

    txt = "Exemplos rotulados (IOB2):\n" + "\n".join(parts)
    return txt[:4000]

# %%
# def _parse_json_loose(s: str):
#     dec = json.JSONDecoder()
#     i, n = 0, len(s)
#     vals = []
#     while i < n:
#         # pula espaços até encontrar um começo plausível
#         while i < n and s[i] not in "[{":
#             i += 1
#         if i >= n:
#             break
#         try:
#             v, j = dec.raw_decode(s, idx=i)
#             vals.append(v)
#             i = j
#         except json.JSONDecodeError:
#             i += 1
#     if not vals:
#         raise json.JSONDecodeError("no JSON found", s, 0)
#     return vals[0] if len(vals) == 1 else vals  # se vários, devolve lista

# class OllamaNER:
#     def __init__(self, model, few_shot_text, host="http://127.0.0.1:11434", keep_alive="30m", options=None, json_mode=True):
#         self.model = model
#         self.keep_alive = keep_alive
#         self.host = host
#         self.json_mode = json_mode
#         self.options = options or {
#             "temperature": 0,   # determinístico e ligeiramente mais rápido
#             # Dica: ajuste num_ctx para caber few-shot + entrada + saída com folga
#             "num_ctx": 6000,
#         }
#         self.sess = requests.Session()

#         few_shot_block = _format_few_shot_block(few_shot_text)

#         # ☑️ Envia o few-shot só uma vez (contexto “quase fixo”)
#         self._base_messages = [
#             {
#                 "role": "system",
#                 "content": (
#                     "Você é um rotulador NER. Dado um array de tokens, devolva rótulos IOB2 "
#                     """Regras (case-sensitive):
#                         1) Use apenas os rótulos:\n{iob_labels}

#                         2) IOB2 (cheque silenciosamente):
#                         • Uma entidade inicia em B-<TIPO>.
#                         • I-<TIPO> só após B-<TIPO> ou I-<TIPO> do mesmo TIPO.
#                         • Nunca iniciar com I-.

#                         3) Formato ÚNICO de saída (sem texto extra):
#                         • Uma única linha com N pares índice-rótulo (1-based), separados por espaço.
#                         • Cada par: <índice>-<RÓTULO>.
#                         • Ex.: 1-O 2-B-magmaticas 3-I-magmaticas ... N-O

#                         4) Se houver N palavras, produza exatamente N rótulos."""
#                     "EXCLUSIVAMENTE como JSON válido. NUNCA explique. Apenas JSON."
#                 ),
#             },
#             {"role": "user", "content": few_shot_block},
#             {"role": "assistant", "content": "OK"},
#         ]

#     def _chat_stream(self, user_content, connect_read_timeout=(5, 90)):
#         payload = {
#             "model": self.model,
#             "keep_alive": self.keep_alive,
#             "stream": True,
#             "messages": self._base_messages + [{"role": "user", "content": user_content}],
#             "options": self.options,
#         }
#         # ⚠️ não force format=json no streaming (alguns builds bufferizam)
#         with self.sess.post(
#             f"{self.host}/api/chat",
#             json=payload,
#             headers={"Accept": "text/event-stream"},
#             timeout=connect_read_timeout,
#             stream=True,
#         ) as r:
#             r.raise_for_status()
#             r.encoding = "utf-8"
#             chunks, got_any = [], False
#             start_t = time.time()

#             for line in r.iter_lines(decode_unicode=True, chunk_size=1):
#                 if not line:
#                     if time.time() - start_t > connect_read_timeout[1] - 1:
#                         break
#                     continue
#                 # aceita “data:{...}” (SSE) e linha pura “{...}” (NDJSON)
#                 payload_str = line[5:].strip() if line.startswith("data:") else line.strip()
#                 try:
#                     evt = json.loads(payload_str)
#                 except Exception:
#                     continue
#                 got_any = True
#                 part = evt.get("message", {}).get("content", "")
#                 if part:
#                     chunks.append(part)
#                 if evt.get("done"):
#                     break

#         raw = "".join(chunks).strip()
#         if raw.startswith("```"):
#             raw = re.sub(r"^```(?:json)?\s*", "", raw)
#             raw = re.sub(r"\s*```$", "", raw)
#         return raw if got_any else ""

#     # mantenha seu _normalize_ner_batch_json como está

#     def _normalize_ner_batch_json(self, obj):
#         if isinstance(obj, dict):
#             if "id" in obj and ("tags" in obj or "tokens" in obj):
#                 tags = obj.get("tags") or obj.get("tokens")
#                 return [{"id": obj.get("id", 0), "tags": tags}]
#             if all(isinstance(k, str) for k in obj.keys()):
#                 out = []
#                 try:
#                     for k in sorted(obj.keys(), key=lambda x: int(x)):
#                         v = obj[k]
#                         if isinstance(v, dict):
#                             tags = v.get("tags") or v.get("tokens") or v.get("labels") or v
#                         else:
#                             tags = v
#                         if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
#                             out.append({"id": int(k), "tags": tags})
#                         else:
#                             raise ValueError("Formato não reconhecido em item indexado.")
#                     return out
#                 except Exception:
#                     pass
#             for key in ("results", "data", "output"):
#                 if key in obj:
#                     return self._normalize_ner_batch_json(obj[key])
#             raise ValueError(f"Formato JSON não reconhecido (dict): {obj}")

#         if isinstance(obj, list):
#             if not obj:
#                 return []
#             if isinstance(obj[0], dict):
#                 norm = []
#                 for i, rec in enumerate(obj):
#                     tags = rec.get("tags") if "tags" in rec else rec.get("tokens") if "tokens" in rec else rec
#                     rid = rec.get("id", i)
#                     if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
#                         norm.append({"id": rid, "tags": tags})
#                     else:
#                         if isinstance(rec, dict) and "tags" not in rec and "tokens" not in rec:
#                             for key in ("tags", "tokens", "labels", "ner"):
#                                 if key in rec:
#                                     tags = rec[key]; break
#                             if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
#                                 norm.append({"id": rid, "tags": tags})
#                             else:
#                                 raise ValueError(f"Item sem tags reconhecíveis: {rec}")
#                         else:
#                             raise ValueError(f"Item sem tags reconhecíveis: {rec}")
#                 return norm
#             if isinstance(obj[0], list) and all(isinstance(t, str) for t in obj[0]):
#                 return [{"id": i, "tags": tags} for i, tags in enumerate(obj)]
#             if all(isinstance(t, str) for t in obj):
#                 return [{"id": 0, "tags": obj}]
#             raise ValueError(f"Formato JSON não reconhecido (list): {obj}")

#         raise ValueError(f"Tipo JSON não reconhecido: {type(obj).__name__}")

#     def tag_batch(self, batch_tokens):
#         # 1) dimensiona num_predict para o lote atual (≈ 1 tag por token + folga)
#         expected = sum(len(t) for t in batch_tokens)
#         buffer   = 8 * max(1, len(batch_tokens))
#         opts = dict(self.options)
#         opts["num_predict"] = max(int(opts.get("num_predict", 0) or 0), expected + buffer)
#         self.options = opts  # simples e eficaz; se preferir, passe via payload local

#         inp = [{"id": i, "tokens": toks} for i, toks in enumerate(batch_tokens)]
#         prompt = (
#             "Rotule cada token no esquema IOB2. Use SOMENTE JSON no formato: "
#             "[ {\"id\": int, \"tags\": [\"O\"|\"B-...\"|\"I-...\"]}, ... ]\n"
#             "ENTRADA:\n" + json.dumps(inp, ensure_ascii=False)
#         )

#         # 2) tenta streaming; se vier vazio, faz fallback non-stream com format=json
#         try:
#             raw = self._chat_stream(prompt, connect_read_timeout=(5, 90))
#         except (ReadTimeout, ConnectionError):
#             raw = ""  # força fallback

#         if not raw:
#             # fallback sem stream, aqui pode forçar JSON completo
#             payload = {
#                 "model": self.model,
#                 "keep_alive": self.keep_alive,
#                 "stream": False,
#                 "messages": self._base_messages + [{"role": "user", "content": prompt}],
#                 "options": self.options,
#             }
#             if self.json_mode:
#                 payload["format"] = "json"
#             r = self.sess.post(f"{self.host}/api/chat", json=payload, timeout=(5, 600))
#             r.raise_for_status()
#             raw = r.json().get("message", {}).get("content", "") or ""

#         # 3) parse robusto
#         try:
#             parsed = json.loads(raw)
#         except Exception:
#             try:
#                 parsed = _parse_json_loose(raw)  # aceita NDJSON/valores múltiplos
#             except Exception:
#                 # Se ainda falhar, bisecta o batch (provável truncamento)
#                 if len(batch_tokens) > 1:
#                     mid = len(batch_tokens) // 2
#                     left  = self.tag_batch(batch_tokens[:mid])
#                     right = self.tag_batch(batch_tokens[mid:])
#                     return left + right
#                 # 1 exemplo só: tenta reemitir com num_predict maior e sem json_mode
#                 opts2 = dict(self.options); opts2["num_predict"] = max(opts2["num_predict"], expected + 128)
#                 jm = self.json_mode; self.json_mode = False
#                 try:
#                     raw2 = self._chat_stream(prompt, connect_read_timeout=(5, 120))
#                     parsed = json.loads(raw2) if raw2 else _parse_json_loose(raw2)
#                 finally:
#                     self.json_mode = jm

#         records = self._normalize_ner_batch_json(parsed)
#         out_sorted = sorted(records, key=lambda x: x["id"])
#         tags = [rec["tags"] for rec in out_sorted]

#         # 4) sanidade de comprimento
#         for i, (toks, tg) in enumerate(zip(batch_tokens, tags)):
#             if len(tg) != len(toks):
#                 tags[i] = (tg[: len(toks)]) if len(tg) > len(toks) else (tg + ["O"] * (len(toks) - len(tg)))
#         if len(tags) < len(batch_tokens):
#             for j in range(len(tags), len(batch_tokens)):
#                 tags.append(["O"] * len(batch_tokens[j]))
#         return tags

# %%
def _parse_json_loose(s: str):
    dec = json.JSONDecoder()
    i, n = 0, len(s)
    vals = []
    while i < n:
        # pula espaços até encontrar um começo plausível
        while i < n and s[i] not in "[{":
            i += 1
        if i >= n:
            break
        try:
            v, j = dec.raw_decode(s, idx=i)
            vals.append(v)
            i = j
        except json.JSONDecodeError:
            i += 1
    if not vals:
        raise json.JSONDecodeError("no JSON found", s, 0)
    return vals[0] if len(vals) == 1 else vals  # se vários, devolve lista

class OllamaNER:
    def __init__(self, model, few_shot_text, host="http://127.0.0.1:11434", keep_alive="30m", options=None, json_mode=True):
        self.model = model
        self.keep_alive = keep_alive
        self.host = host
        self.json_mode = json_mode
        self.options = options or {
            "temperature": 0,   # determinístico e ligeiramente mais rápido
            # Dica: ajuste num_ctx para caber few-shot + entrada + saída com folga
            "num_ctx": 6000,
        }
        self.sess = requests.Session()

        few_shot_block = _format_few_shot_block(few_shot_text)

        # ☑️ Envia o few-shot só uma vez (contexto “quase fixo”)
        self._base_messages = [
            {
                "role": "system",
                "content": (
                    "Você é um rotulador NER. Dado um array de tokens, devolva rótulos IOB2 "
                    """Regras (case-sensitive):
                        1) Use apenas os rótulos:\n{iob_labels}

                        2) IOB2 (cheque silenciosamente):
                        • Uma entidade inicia em B-<TIPO>.
                        • I-<TIPO> só após B-<TIPO> ou I-<TIPO> do mesmo TIPO.
                        • Nunca iniciar com I-.

                        3) Formato ÚNICO de saída (sem texto extra):
                        • Uma única linha com N pares índice-rótulo (1-based), separados por espaço.
                        • Cada par: <índice>-<RÓTULO>.
                        • Ex.: 1-O 2-B-magmaticas 3-I-magmaticas ... N-O

                        4) Se houver N palavras, produza exatamente N rótulos."""
                    "EXCLUSIVAMENTE como JSON válido. NUNCA explique. Apenas JSON."
                ),
            },
            {"role": "user", "content": few_shot_block},
            {"role": "assistant", "content": "OK"},
        ]

    def _chat_stream(self, user_content, connect_read_timeout=(5, 90)):
        payload = {
            "model": self.model,
            "keep_alive": self.keep_alive,
            "stream": True,
            "messages": self._base_messages + [{"role": "user", "content": user_content}],
            "options": self.options,
        }
        # ⚠️ não force format=json no streaming (alguns builds bufferizam)
        with self.sess.post(
            f"{self.host}/api/chat",
            json=payload,
            headers={"Accept": "text/event-stream"},
            timeout=connect_read_timeout,
            stream=True,
        ) as r:
            r.raise_for_status()
            r.encoding = "utf-8"
            chunks, got_any = [], False
            start_t = time.time()

            for line in r.iter_lines(decode_unicode=True, chunk_size=1):
                if not line:
                    if time.time() - start_t > connect_read_timeout[1] - 1:
                        break
                    continue
                # aceita “data:{...}” (SSE) e linha pura “{...}” (NDJSON)
                payload_str = line[5:].strip() if line.startswith("data:") else line.strip()
                try:
                    evt = json.loads(payload_str)
                except Exception:
                    continue
                got_any = True
                part = evt.get("message", {}).get("content", "")
                if part:
                    chunks.append(part)
                if evt.get("done"):
                    break

        raw = "".join(chunks).strip()
        if raw.startswith("```"):
            raw = re.sub(r"^```(?:json)?\s*", "", raw)
            raw = re.sub(r"\s*```$", "", raw)
        return raw if got_any else ""

    # mantenha seu _normalize_ner_batch_json como está

    def _normalize_ner_batch_json(self, obj):
        if isinstance(obj, dict):
            if "id" in obj and ("tags" in obj or "tokens" in obj):
                tags = obj.get("tags") or obj.get("tokens")
                return [{"id": obj.get("id", 0), "tags": _coerce_tags_list(tags)}]
            if all(isinstance(k, str) for k in obj.keys()):
                out = []
                try:
                    for k in sorted(obj.keys(), key=lambda x: int(x)):
                        v = obj[k]
                        if isinstance(v, dict):
                            tags = v.get("tags") or v.get("tokens") or v.get("labels") or v
                        else:
                            tags = v
                        if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
                            out.append({"id": int(k), "tags": tags})
                        else:
                            raise ValueError("Formato não reconhecido em item indexado.")
                    return out
                except Exception:
                    pass
            for key in ("results", "data", "output"):
                if key in obj:
                    return self._normalize_ner_batch_json(obj[key])
            raise ValueError(f"Formato JSON não reconhecido (dict): {obj}")

        if isinstance(obj, list):
            if not obj:
                return []
            if isinstance(obj[0], dict):
                norm = []
                for i, rec in enumerate(obj):
                    tags = rec.get("tags") if "tags" in rec else rec.get("tokens") if "tokens" in rec else rec
                    rid = rec.get("id", i)
                    tags = _coerce_tags_list(tags)
                    if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
                        norm.append({"id": rid, "tags": tags})
                    else:
                        if isinstance(rec, dict) and "tags" not in rec and "tokens" not in rec:
                            for key in ("tags", "tokens", "labels", "ner"):
                                if key in rec:
                                    tags = rec[key]; break
                            if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
                                norm.append({"id": rid, "tags": tags})
                            else:
                                raise ValueError(f"Item sem tags reconhecíveis: {rec}")
                        else:
                            raise ValueError(f"Item sem tags reconhecíveis: {rec}")
                return norm
            if isinstance(obj[0], list) and all(isinstance(t, str) for t in obj[0]):
                return [{"id": i, "tags": tags} for i, tags in enumerate(obj)]
            if all(isinstance(t, str) for t in obj):
                return [{"id": 0, "tags": _coerce_tags_list(obj)}] 
            raise ValueError(f"Formato JSON não reconhecido (list): {obj}")

        raise ValueError(f"Tipo JSON não reconhecido: {type(obj).__name__}")

    def tag_batch(self, batch_tokens):
        # 1) dimensiona num_predict para o lote atual (≈ 1 tag por token + folga)
        expected = sum(len(t) for t in batch_tokens)
        buffer   = 8 * max(1, len(batch_tokens))
        opts = dict(self.options)
        opts["num_predict"] = max(int(opts.get("num_predict", 0) or 0), expected + buffer)
        self.options = opts  # simples e eficaz; se preferir, passe via payload local

        inp = [{"id": i, "tokens": toks} for i, toks in enumerate(batch_tokens)]
        prompt = (
            "Rotule cada token no esquema IOB2. Use SOMENTE JSON no formato: "
            "[ {\"id\": int, \"tags\": [\"O\"|\"B-...\"|\"I-...\"]}, ... ]\n"
            "ENTRADA:\n" + json.dumps(inp, ensure_ascii=False)
        )

        # 2) tenta streaming; se vier vazio, faz fallback non-stream com format=json
        try:
            raw = self._chat_stream(prompt, connect_read_timeout=(5, 90))
        except (ReadTimeout, ConnectionError):
            raw = ""  # força fallback

        if not raw:
            # fallback sem stream, aqui pode forçar JSON completo
            payload = {
                "model": self.model,
                "keep_alive": self.keep_alive,
                "stream": False,
                "messages": self._base_messages + [{"role": "user", "content": prompt}],
                "options": self.options,
            }
            if self.json_mode:
                payload["format"] = "json"
            r = self.sess.post(f"{self.host}/api/chat", json=payload, timeout=(5, 600))
            r.raise_for_status()
            raw = r.json().get("message", {}).get("content", "") or ""

        # 3) parse robusto
        try:
            parsed = json.loads(raw)
        except Exception:
            try:
                parsed = _parse_json_loose(raw)  # seu parser “solto” que aceita NDJSON/múltiplos valores
            except Exception:
                parsed = None

        # 3.1) Se parseou mas NÃO tem 'tags' (eco da entrada ou formato errado), re-pergunte sem stream
        if (parsed is None) or _looks_like_echo(parsed) or not _has_tags_struct(parsed):
            # prompt de reparo: enfatiza que NÃO deve repetir a entrada nem usar chave 'tokens'
            repair_prompt = (
                "NÃO REPITA A ENTRADA. Devolva SOMENTE JSON no formato exato: "
                "[{\"id\": int, \"tags\": [\"O\"|\"B-...\"|\"I-...\"]}, ...]\n"
                "Não inclua a chave 'tokens'.\n"
                "ENTRADA:\n" + json.dumps(inp, ensure_ascii=False)
            )
            # non-stream + format=json para forçar JSON completo
            payload = {
                "model": self.model,
                "keep_alive": self.keep_alive,
                "stream": False,
                "messages": self._base_messages + [{"role": "user", "content": repair_prompt}],
                "options": self.options,
            }
            if self.json_mode:
                payload["format"] = "json"

            r = self.sess.post(f"{self.host}/api/chat", json=payload, timeout=(5, 600))
            r.raise_for_status()
            raw2 = r.json().get("message", {}).get("content", "") or ""

            try:
                parsed2 = json.loads(raw2)
            except Exception:
                try:
                    parsed2 = _parse_json_loose(raw2)
                except Exception:
                    parsed2 = None

            if (parsed2 is None) or _looks_like_echo(parsed2) or not _has_tags_struct(parsed2):
                # ainda ruim → bisecta o batch (isola o exemplo problemático)
                if len(batch_tokens) > 1:
                    mid = len(batch_tokens) // 2
                    left  = self.tag_batch(batch_tokens[:mid])
                    right = self.tag_batch(batch_tokens[mid:])
                    return left + right
                # 1 único exemplo e ainda eco? decida política:
                #  a) levantar erro:
                raise BadModelOutput("Modelo não retornou 'tags'; ecoou 'tokens'.")
                #  b) (opcional) fallback benigno: tudo 'O'
                # return [["O"] * len(batch_tokens[0])]

            parsed = parsed2  # ok, seguimos com o reparo

        records = self._normalize_ner_batch_json(parsed)
        out_sorted = sorted(records, key=lambda x: x["id"])
        tags = [rec["tags"] for rec in out_sorted]

        # sanidade de comprimento
        for i, (toks, tg) in enumerate(zip(batch_tokens, tags)):
            if len(tg) != len(toks):
                tags[i] = (tg[: len(toks)]) if len(tg) > len(toks) else (tg + ["O"] * (len(toks) - len(tg)))
        if len(tags) < len(batch_tokens):
            for j in range(len(tags), len(batch_tokens)):
                tags.append(["O"] * len(batch_tokens[j]))
        return tags

# %%
# class OllamaNER:
#     def __init__(self, model, few_shot_text, host="http://127.0.0.1:11434", keep_alive="30m", options=None, json_mode=True):
#         self.model = model
#         self.keep_alive = keep_alive
#         self.host = host
#         self.json_mode = json_mode
#         self.options = options or {
#             "temperature": 0,   # determinístico e ligeiramente mais rápido
#             # Dica: ajuste num_ctx para caber few-shot + entrada + saída com folga
#             "num_ctx": 6000,
#         }
#         self.sess = requests.Session()

#         few_shot_block = _format_few_shot_block(few_shot_text)

#         # ☑️ Envia o few-shot só uma vez (contexto “quase fixo”)
#         self._base_messages = [
#             {
#                 "role": "system",
#                 "content": (
#                     "Você é um rotulador NER. Dado um array de tokens, devolva rótulos IOB2 "
#                     """Regras (case-sensitive):
#                         1) Use apenas os rótulos:\n{iob_labels}

#                         2) IOB2 (cheque silenciosamente):
#                         • Uma entidade inicia em B-<TIPO>.
#                         • I-<TIPO> só após B-<TIPO> ou I-<TIPO> do mesmo TIPO.
#                         • Nunca iniciar com I-.

#                         3) Formato ÚNICO de saída (sem texto extra):
#                         • Uma única linha com N pares índice-rótulo (1-based), separados por espaço.
#                         • Cada par: <índice>-<RÓTULO>.
#                         • Ex.: 1-O 2-B-magmaticas 3-I-magmaticas ... N-O

#                         4) Se houver N palavras, produza exatamente N rótulos."""
#                     "EXCLUSIVAMENTE como JSON válido. NUNCA explique. Apenas JSON."
#                 ),
#             },
#             {"role": "user", "content": few_shot_block},
#             {"role": "assistant", "content": "OK"},
#         ]

    
#     def _normalize_ner_batch_json(self, obj):
#         if isinstance(obj, dict):
#             if "id" in obj and ("tags" in obj or "tokens" in obj):
#                 tags = obj.get("tags") or obj.get("tokens")
#                 return [{"id": obj.get("id", 0), "tags": tags}]
#             if all(isinstance(k, str) for k in obj.keys()):
#                 out = []
#                 try:
#                     for k in sorted(obj.keys(), key=lambda x: int(x)):
#                         v = obj[k]
#                         if isinstance(v, dict):
#                             tags = v.get("tags") or v.get("tokens") or v.get("labels") or v
#                         else:
#                             tags = v
#                         if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
#                             out.append({"id": int(k), "tags": tags})
#                         else:
#                             raise ValueError("Formato não reconhecido em item indexado.")
#                     return out
#                 except Exception:
#                     pass
#             for key in ("results", "data", "output"):
#                 if key in obj:
#                     return self._normalize_ner_batch_json(obj[key])
#             raise ValueError(f"Formato JSON não reconhecido (dict): {obj}")

#         if isinstance(obj, list):
#             if not obj:
#                 return []
#             if isinstance(obj[0], dict):
#                 norm = []
#                 for i, rec in enumerate(obj):
#                     tags = rec.get("tags") if "tags" in rec else rec.get("tokens") if "tokens" in rec else rec
#                     rid = rec.get("id", i)
#                     if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
#                         norm.append({"id": rid, "tags": tags})
#                     else:
#                         if isinstance(rec, dict) and "tags" not in rec and "tokens" not in rec:
#                             for key in ("tags", "tokens", "labels", "ner"):
#                                 if key in rec:
#                                     tags = rec[key]; break
#                             if isinstance(tags, list) and all(isinstance(t, str) for t in tags):
#                                 norm.append({"id": rid, "tags": tags})
#                             else:
#                                 raise ValueError(f"Item sem tags reconhecíveis: {rec}")
#                         else:
#                             raise ValueError(f"Item sem tags reconhecíveis: {rec}")
#                 return norm
#             if isinstance(obj[0], list) and all(isinstance(t, str) for t in obj[0]):
#                 return [{"id": i, "tags": tags} for i, tags in enumerate(obj)]
#             if all(isinstance(t, str) for t in obj):
#                 return [{"id": 0, "tags": obj}]
#             raise ValueError(f"Formato JSON não reconhecido (list): {obj}")

#         raise ValueError(f"Tipo JSON não reconhecido: {type(obj).__name__}")


#     def _chat_stream(self, user_content, connect_read_timeout=(5, 600)):
#         payload = {
#             "model": self.model,
#             "keep_alive": self.keep_alive,
#             "stream": True,  # streaming = evita ReadTimeout e evita r.json()
#             "messages": self._base_messages + [{"role": "user", "content": user_content}],
#             "options": self.options,
#         }


#         if self.json_mode:
#             # Obriga JSON “puro” (reduz pós-processamento e tokens gerados)
#             payload["format"] = "json"

#         with self.sess.post(
#         f"{self.host}/api/chat",
#         json=payload,
#         headers={"Accept": "text/event-stream"},
#         timeout=connect_read_timeout,  # (connect, read)
#         stream=True
#         ) as r:
#             r.raise_for_status()
#             r.encoding = "utf-8"  # garante str no iter_lines
#             chunks = []
#             got_any = False
#             start_t = time.time()

#             for line in r.iter_lines(decode_unicode=True, chunk_size=1):
#                 if not line:
#                     if time.time() - start_t > connect_read_timeout[1] - 1:
#                         break
#                     continue

#                 # Aceita SSE (data: {...}) e NDJSON (linha é {...})
#                 payload_str = line[5:].strip() if line.startswith("data:") else line.strip()

#                 try:
#                     evt = json.loads(payload_str)
#                 except Exception:
#                     # debug opcional:
#                     # print("linha não-JSON:", repr(line[:120]))
#                     continue

#                 got_any = True
#                 part = evt.get("message", {}).get("content", "")
#                 if part:
#                     chunks.append(part)
#                 if evt.get("done"):
#                     break

#             raw = "".join(chunks).strip()
#             # limpa cercas ```json ... ```
#             if raw.startswith("```"):
#                 raw = re.sub(r"^```(?:json)?\s*", "", raw)
#                 raw = re.sub(r"\s*```$", "", raw)

#             # se nada chegou pelo stream, devolva "" para acionar fallback non-stream
#             return raw if got_any else ""

#     def tag_batch(self, batch_tokens):
#         """
#         batch_tokens: List[List[str]] (vários exemplos em uma chamada)
#         Retorna: List[List[str]] na mesma ordem.
#         """
#         # ⚠️ Pedimos uma lista de objetos { "id": int, "tags": [...] } para manter ordenação
#         inp = [{"id": i, "tokens": toks} for i, toks in enumerate(batch_tokens)]
#         prompt = (
#             "Rotule cada token no esquema IOB2. Rótulos permitidos já foram definidos no few-shot.\n"
#             "ENTRADA:\n" + json.dumps(inp, ensure_ascii=False) + "\n\n"
#             "SAÍDA (JSON ESTRITO):\n"
#             "[ {\"id\": int, \"tags\": [\"O\"|\"B-...\"|\"I-...\"]}, ... ]\n"
#         )

#         try:
#             raw = self._chat_stream(prompt, connect_read_timeout=(5, 600))
#         except (ReadTimeout, ConnectionError):
#             if len(batch_tokens) == 1:
#                 raw = self._chat_stream(prompt, connect_read_timeout=(5, 1200))
#             else:
#                 mid = len(batch_tokens) // 2
#                 left  = self.tag_batch(batch_tokens[:mid])
#                 right = self.tag_batch(batch_tokens[mid:])
#                 return left + right

#         # --- parsing robusto do JSON ---
#         try:
#             out = json.loads(raw)
#         except Exception:
#             # Reparo simples: pega o primeiro '[' até o último ']'
#             start, end = raw.find("["), raw.rfind("]") + 1
#             if start != -1 and end > start:
#                 out = json.loads(raw[start:end])
#             else:
#                 start, end = raw.find("{"), raw.rfind("}") + 1
#                 out = json.loads(raw[start:end])

#         records = self._normalize_ner_batch_json(out)
#         out_sorted = sorted(records, key=lambda x: x["id"])
#         tags = [rec["tags"] for rec in out_sorted]

#         # Segurança: garante mesmo tamanho de cada exemplo
#         for i, (toks, tg) in enumerate(zip(batch_tokens, tags)):
#             if len(tg) != len(toks):
#                 # Heurística: corta ou preenche com 'O'
#                 if len(tg) > len(toks):
#                     tags[i] = tg[: len(toks)]
#                 else:
#                     tags[i] = tg + ["O"] * (len(toks) - len(tg))
#         return tags

# %%
def ollama_generate(
    model: str,
    prompt: str,
    options: Optional[Dict[str, Any]] = None,
    host: str = "http://localhost:11434",
    timeout: int = 120,
    stream: bool = False,
) -> str:
    """
    Wrapper do endpoint /api/generate.
    """
    url = f"{host}/api/generate"
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": stream,
        "options": options or {},
        # "stop": ["\n\n"],  # ajuste opcional se algum modelo insistir em linhas extras
    }
    # Timeout levemente alto pois alguns modelos podem demorar.
    resp = requests.post(url, json=payload, timeout=timeout)
    resp.raise_for_status()

    if stream:
        # Se usar stream=True, agregamos as linhas 'data: {...}'
        text = ""
        for line in resp.iter_lines():
            if not line:
                continue
            try:
                obj = json.loads(line.decode("utf-8"))
            except Exception:
                continue
            text += obj.get("response", "")
        return text
    else:
        data = resp.json()
        return data.get("response", "")

# %%
def predict_labels_ollama(few_shot, query_tokens, model_key=MODEL_KEY, host=HOST):
    cfg = OLLAMA_MODELS[model_key]
    prompt = build_prompt(few_shot, query_tokens)
    print(prompt)
    raw = ollama_generate(model=model_key, prompt=prompt, options=cfg.get("options"), host=host, stream=False)
    return raw

# %%
SESSION = requests.Session()

# %%
def ollama_generate_json(model: str, prompt: str, host="http://127.0.0.1:11434",
                         num_predict:int=64, num_ctx:int=2048, timeout=(10, 600)):
    payload = {
        "model": model,
        "prompt": prompt,
        "format": "json",     # resposta vem como string JSON em data['response']
        "stream": False,      # evita travar se o cliente não consumir stream
        "keep_alive": "30m",
        "options": {
            "temperature": 0,
            "seed": 42,
            "num_ctx": num_ctx*30,
            "num_predict": max(64, 5 * num_predict)
        }
    }
    return SESSION.post(f"{host}/api/generate", json=payload, timeout=timeout)

# %%
def predict_labels_ollama(tokens: List[str],
                          few_shot_text: str = "",
                          model: str = "llama3.1:8b") -> List[str]:
    # prompt curto e objetivo; evite few-shots gigantes (cole 1–2 exemplos no few_shot_text)
    
    N = len(tokens)
    prompt = build_prompt(few_shot_text, tokens)
    # retry leve para 5xx/timeout
    for attempt in range(3):
        try:
            r = ollama_generate_json(
                model=model,
                prompt=prompt,
                # use o número de tokens como base para calcular num_predict interno
                num_predict=min(64, 3 * len(tokens)),
                num_ctx=N
            )
            r.raise_for_status()
            data = r.json()
            attempt = 3
            return data['response']
        except Exception:
            if attempt == 2:
                raise
            time.sleep(1.5 * (attempt + 1))

# %%
class BadModelOutput(Exception):
    pass

def _has_tags_struct(x):
    try:
        items = x if isinstance(x, list) else [x]
        for it in items:
            if isinstance(it, list):
                # lista de registros
                for r in it:
                    if isinstance(r, dict) and isinstance(r.get("tags"), list):
                        return True
            elif isinstance(it, dict) and isinstance(it.get("tags"), list):
                return True
        return False
    except Exception:
        return False

def _looks_like_echo(x):
    # lista (ou lista de listas) de dicts com 'tokens' e sem 'tags'
    try:
        if isinstance(x, list) and x:
            first = x[0]
            if isinstance(first, list) and first and isinstance(first[0], dict):
                return all(("tokens" in d and "tags" not in d) for d in first)
            if isinstance(first, dict):
                return ("tokens" in first and "tags" not in first)
        if isinstance(x, dict):
            return ("tokens" in x and "tags" not in x)
    except Exception:
        return False
    return False

# %%
def _coerce_tag_value(d):
    # tenta chaves comuns de IOB2
    for key in ("tag", "label", "iob", "iob_tag", "ner", "entity", "type"):
        v = d.get(key)
        if isinstance(v, str):
            v = v.strip()
            # aceita O, B-..., I-...
            if v == "O" or re.match(r"^[BI]-", v):
                return v
    # se nada servir, marca como O
    return "O"

def _coerce_tags_list(x):
    """
    x: pode ser lista de strings OU lista de dicts (word/type, etc.)
    retorna sempre lista de strings (IOB2-like), substituindo inválidos por 'O'
    """
    if not isinstance(x, list):
        return []
    if all(isinstance(t, str) for t in x):
        return x
    if all(isinstance(t, dict) for t in x):
        return [_coerce_tag_value(t) for t in x]
    # mix estranho: tenta extrair, senão devolve tudo 'O'
    out = []
    for t in x:
        if isinstance(t, str):
            out.append(t if (t == "O" or re.match(r"^[BI]-", t or "")) else "O")
        elif isinstance(t, dict):
            out.append(_coerce_tag_value(t))
        else:
            out.append("O")
    return out

# %%
FAILED_LOG  = DIR_LOGS  / "ner_failed_indices.log" 

def log_fail(split_name, idx, reason):
    with open(FAILED_LOG, "a", encoding="utf-8") as f:
        f.write(json.dumps({"split": split_name, "idx": idx, "err": str(reason)}) + "\n")

def get_checkpoint_path(nome: str) -> Path:
    """Caminho do checkpoint do split 'nome', por modelo."""
    return DIR_CKPT / f"{SAFE_MODEL}__{nome}.ckpt.json"

def load_checkpoint(nome):
    p = get_checkpoint_path(nome)
    if os.path.exists(p):
        try:
            return int(json.load(open(p, "r", encoding="utf-8")).get("next_idx", 0))
        except Exception:
            return 0
    return 0

def save_checkpoint(nome, next_idx):
    with open(get_checkpoint_path(nome), "w", encoding="utf-8") as f:
        json.dump({"next_idx": int(next_idx)}, f)

# %% [markdown]
# # Prompts

# %%
# few_shot = [
#     {"tokens": ["o", "maj", "é", "composto"], "tags": ["O","O","O","O"]},
#     {"tokens": ["dioritos", "e", "monzodioritos"], "tags": ["B-magmaticas","O","I-magmaticas"]},
# ]
# query_tokens = ["o","maj","é","composto","por","monzodioritos","."]
# preds = predict_labels_ollama(few_shot, query_tokens)  # usa MODEL_KEY
# preds

# %%
splits = [standard_split, heur_len, heur_rare, advers]

# %%
splits_names = ['standard', 'heur_len', 'heur_rare', 'adversarial']

# %%
MODEL_KEY
# Out:
# 'gemma2:9b'

# %%
model_escolhido = MODEL_KEY

# %%
def run_fast_inference(
    splits, splits_names, model_escolhido, FEW_SHOT_K, select_few_shot, SEED_GLOBAL
):
    random.seed(SEED_GLOBAL)

    golds, predictions = {}, {}
    cache = _load_cache(CACHE_PATH)

    for split, nome in zip(splits, splits_names):
        split_base = split
        total = min(500, len(split_base["test"]))  # ajuste se quiser rodar tudo
        few_shot = select_few_shot(split_base["train"], FEW_SHOT_K)

        ner = OllamaNER(
            model=model_escolhido,
            few_shot_text=few_shot,
            options={
                "temperature": 0,
                "num_ctx": 768,
                "num_predict": 1536,
            },
            keep_alive="10m",
            json_mode=True,
        )

        all_test = list(split_base["test"].select(range(total)))
        split_salt = f"split:{nome}"
        BATCH_SIZE = 5

        # Pré-aloca
        golds[nome] = [None] * total
        predictions[nome] = [None] * total

        # Retomada: onde paramos?
        start_idx = load_checkpoint(nome)

        # Preenche rapidamente os índices anteriores usando o cache (se existir)
        if start_idx > 0:
            for ex_idx in range(0, min(start_idx, total)):
                ex = all_test[ex_idx]
                golds[nome][ex_idx] = [ex["ner_tags"]]
                k = _hash_key(ex["tokens"], model_escolhido, shot_id=split_salt)
                if k in cache and predictions[nome][ex_idx] is None:
                    predictions[nome][ex_idx] = [cache[k]]
            # Garantia: se algum anterior continuar None, deixamos p/ reprocessar abaixo
            # (mas o loop começa em start_idx, então não atrapalha)

        pending_tokens, pending_idx = [], []

        t0 = time.time()
        for ex_idx, ex in enumerate(tqdm(all_test[start_idx:], desc=f"Inferindo: {nome}"), start=start_idx):
            tokens = ex["tokens"]
            k = _hash_key(tokens, model_escolhido, shot_id=split_salt)

            golds[nome][ex_idx] = [ex["ner_tags"]]

            if k in cache:
                # cache hit -> escreve e avança checkpoint
                predictions[nome][ex_idx] = [cache[k]]
                save_checkpoint(nome, ex_idx + 1)
            else:
                pending_tokens.append(tokens)
                pending_idx.append(ex_idx)

                # Quando o batch enche, consulta o LLM uma vez
                if len(pending_tokens) >= BATCH_SIZE:
                    try:
                        batch_tags = ner.tag_batch(pending_tokens)
                    except Exception as e:
                        # Fallback: processa 1 a 1; se falhar, põe 'O' e loga
                        batch_tags = []
                        for toks, idx_buf in zip(pending_tokens, pending_idx):
                            try:
                                one = ner.tag_batch([toks])[0]
                            except Exception as ee:
                                one = ["O"] * len(toks)
                                log_fail(nome, idx_buf, ee)
                            batch_tags.append(one)

                    # cacheia e escreve por índice
                    for toks, tags in zip(pending_tokens, batch_tags):
                        kk = _hash_key(toks, model_escolhido, shot_id=split_salt)
                        cache[kk] = tags
                        _append_cache(CACHE_PATH, kk, tags)

                    for idx_buf, tags in zip(pending_idx, batch_tags):
                        predictions[nome][idx_buf] = [tags]
                        save_checkpoint(nome, idx_buf + 1)  # avança sempre

                    pending_tokens, pending_idx = [], []

        # Flush final se sobrou algo
        if pending_tokens:
            try:
                batch_tags = ner.tag_batch(pending_tokens)
            except Exception as e:
                batch_tags = []
                for toks, idx_buf in zip(pending_tokens, pending_idx):
                    try:
                        one = ner.tag_batch([toks])[0]
                    except Exception as ee:
                        one = ["O"] * len(toks)
                        log_fail(nome, idx_buf, ee)
                    batch_tags.append(one)

            for toks, tags in zip(pending_tokens, batch_tags):
                kk = _hash_key(toks, model_escolhido, shot_id=split_salt)
                cache[kk] = tags
                _append_cache(CACHE_PATH, kk, tags)

            for idx_buf, tags in zip(pending_idx, batch_tags):
                predictions[nome][idx_buf] = [tags]
                save_checkpoint(nome, idx_buf + 1)

            pending_tokens, pending_idx = [], []

        dt = time.time() - t0
        print(f"[{nome}] Terminado em {dt/60:.2f} min")

    return golds, predictions

# %%
# golds, predictions = {}, {}
# cache = _load_cache(CACHE_PATH)
# for split, nome in zip(splits, splits_names):
#         split_base = split
#         total = 500  # ou len(split_base['test'])
#         few_shot = select_few_shot(split_base["train"], FEW_SHOT_K)
# golds, predictions = {}, {}
# cache = _load_cache(CACHE_PATH)

# split = splits[1]
# nome = splits_names[1]
# split_base = split
# total = 15

# few_shot = select_few_shot(split_base["train"], FEW_SHOT_K)

# ner = OllamaNER(
#             model=model_escolhido,
#             few_shot_text=few_shot,
#             options={
#                 "temperature": 0,
#                 "num_ctx": 768,         # ajuste isso se o few-shot for maior
#                 "num_predict": 1536,    # saída JSON pode ser grande; mantenha folga
#             },
#             keep_alive="10m",
#             json_mode=True,
#         )


# golds[nome] = [None] * total
# predictions[nome] = [None] * total

# # Config de batch (experimente 4, 8, 12 e escolha o melhor no seu hardware)
# BATCH_SIZE = 5

# # ✅ Monta a fila com cache: só manda ao LLM o que não estiver no cache
# pending_tokens = []
# pending_idx = []
# all_test = list(split_base["test"].select(range(total)))
# split_salt = f"split:{nome}"

# t0 = time.time()
# for ex_idx, ex in enumerate(tqdm(all_test, desc=f"Inferindo: {nome}")):
#     tokens = ex["tokens"]
#     k = _hash_key(tokens, model_escolhido, shot_id=split_salt)
#     golds[nome][ex_idx] = [ex["ner_tags"]]

#     if k in cache:
#         # cache hit
#         predictions[nome][ex_idx] = [cache[k]]
#     else:
#         pending_tokens.append(tokens)
#         pending_idx.append(ex_idx)

#         # Quando o batch enche, consulta o LLM uma vez
#         if len(pending_tokens) >= BATCH_SIZE:
#             try:
#                 batch_tags = ner.tag_batch(pending_tokens)
#                 ok = True
#             except Exception as e:
#                 ok = False
#                 # Fallback: processa 1 a 1; se falhar, preenche 'O' e loga
#                 batch_tags = []
#                 for toks, idx_buf in zip(pending_tokens, pending_idx):
#                     try:
#                         one = ner.tag_batch([toks])[0]
#                     except Exception as ee:
#                         one = ["O"] * len(toks)
#                         log_fail(nome, idx_buf, ee)
#                     batch_tags.append(one)

#             # cacheia e escreve por índice
#             for toks, tags in zip(pending_tokens, batch_tags):
#                 kk = _hash_key(toks, model_escolhido, shot_id=split_salt)
#                 cache[kk] = tags
#                 _append_cache(CACHE_PATH, kk, tags)

#             for idx_buf, tags in zip(pending_idx, batch_tags):
#                 predictions[nome][idx_buf] = [tags]
#                 save_checkpoint(nome, idx_buf + 1)  # <<< checkpoint avanço a cada exemplo

#             pending_tokens, pending_idx = [], []
# # Flush final se sobrou algo

# if pending_tokens:
#     try:
#         batch_tags = ner.tag_batch(pending_tokens)
#     except Exception as e:
#         batch_tags = []
#         for toks, idx_buf in zip(pending_tokens, pending_idx):
#             try:
#                 one = ner.tag_batch([toks])[0]
#             except Exception as ee:
#                 one = ["O"] * len(toks)
#                 log_fail(nome, idx_buf, ee)
#             batch_tags.append(one)

#     for toks, tags in zip(pending_tokens, batch_tags):
#         kk = _hash_key(toks, model_escolhido, shot_id=split_salt)
#         cache[kk] = tags
#         _append_cache(CACHE_PATH, kk, tags)

#     for idx_buf, tags in zip(pending_idx, batch_tags):
#         predictions[nome][idx_buf] = [tags]
#         save_checkpoint(nome, idx_buf + 1)

#     pending_tokens, pending_idx = [], []

# dt = time.time() - t0
# print(f"[{nome}] Terminado em {dt/60:.2f} min")

# t0 = time.time()
# for ex_idx, ex in enumerate(tqdm(all_test, desc=f"Inferindo: {nome}")):
#     tokens = ex["tokens"]
#     split_salt = f"split:{nome}"
#     k = _hash_key(tokens, model_escolhido, shot_id=split_salt)
#     golds[nome][ex_idx] = [ex["ner_tags"]]

#     if k in cache:
#         # cache hit
#         predictions[nome][ex_idx] = [cache[k]]
#     else:
#         pending_tokens.append(tokens)
#         pending_idx.append(ex_idx)

#         # Quando o batch enche, consulta o LLM uma vez
#         if len(pending_tokens) >= BATCH_SIZE:
#             batch_tags = ner.tag_batch(pending_tokens)
#             for toks, tags in zip(pending_tokens, batch_tags):
#                 kk = _hash_key(toks, model_escolhido, shot_id=split_salt)
#                 cache[kk] = tags
#                 _append_cache(CACHE_PATH, kk, tags)
#             # escreve nas posições corretas
#             for idx_buf, tags in zip(pending_idx, batch_tags):
#                 predictions[nome][idx_buf] = [tags]
#             pending_tokens, pending_idx = [], []
# # Flush final se sobrou algo

# if pending_tokens:
#     batch_tags = ner.tag_batch(pending_tokens)

#     for toks, tags in zip(pending_tokens, batch_tags):
#         kk = _hash_key(toks, model_escolhido, shot_id=split_salt)
#         cache[kk] = tags
#         _append_cache(CACHE_PATH, kk, tags)

#     for idx_buf, tags in zip(pending_idx, batch_tags):
#         predictions[nome][idx_buf] = [tags]

#     pending_tokens, pending_idx = [], []

# dt = time.time() - t0
# print(f"[{nome}] Terminado em {dt/60:.2f} min")

# %%
golds, predictions = run_fast_inference(
    splits=splits,                      # já existentes no seu notebook
    splits_names=splits_names,          # idem
    model_escolhido=model_escolhido,
    
    FEW_SHOT_K=FEW_SHOT_K,
    select_few_shot=select_few_shot,
    SEED_GLOBAL=SEED_GLOBAL,
)
# Out:
# Inferindo: standard: 100%|██████████| 500/500 [4:28:45<00:00, 32.25s/it]
# [standard] Terminado em 268.76 min
# Inferindo: heur_len: 100%|██████████| 500/500 [6:33:48<00:00, 47.26s/it]
# [heur_len] Terminado em 393.81 min
# Inferindo: heur_rare: 100%|██████████| 500/500 [8:30:26<00:00, 61.25s/it]
# [heur_rare] Terminado em 510.44 min
# Inferindo: adversarial: 100%|██████████| 500/500 [11:28:10<00:00, 82.58s/it]
# [adversarial] Terminado em 688.17 min

# %%
predictions
# Out:
# {'standard': [[['O',
#     'O',
#     'O',
#     'O',
#     'B-paleomesoproterozoico',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-paleomesoproterozoico',
#     'O',
#     'O',
#     'B-windley',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-megaflorísticos',
#     'O',
#     'B-carbonífera',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-carbonífera',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [[{'start': 12, 'end': 23, 'label': 'Bacia do Paraná'},
#     {'start': 47, 'end': 58, 'label': 'Formação de Mira'},
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-evento',
#     'I-evento',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-grupo',
#     'I-grupo',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-época',
#     'I-época',
#     'O',
#     'O',
#     'B-evento',
#     'I-evento',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-material',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-material',
#     'I-material',
#     'O',
#     'O',
#     'B-material',
#     'I-material',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-região',
#     'I-região',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-sucesso',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-NUM',
#     'O',
#     'O',
#     'O',
#     'B-NUM',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-NUM',
#     'O']],
#   [['O', 'O', 'O', 'B-NUM', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ORG',
#     'I-ORG',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'B-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ORG',
#     'I-ORG',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '.',
#     'O']],
#   [['O',
#     'O',
#     'B-PERÍODO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-PERÍODO',
#     'I-PERÍODO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-LOC',
#     'I-LOC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-MISC',
#     'I-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-NUMBER',
#     'I-NUMBER',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-rochas',
#     'I-rochas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-earthcache',
#     'I-earthcache',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-ORG',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-LOC',
#     'I-LOC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-LOC',
#     'I-LOC',
#     'I-LOC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-LOC',
#     'I-LOC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-LOC',
#     'O',
#     'O',
#     'O',
#     'I-LOC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-NUM',
#     'I-NUM',
#     'O',
#     'O',
#     'O',
#     'B-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-PERIODO',
#     'I-PERIODO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-MISC',
#     'O',
#     'B-ROCK_TYPE',
#     'O',
#     'O',
#     'O',
#     'B-MINERAL',
#     'O',
#     'B-MINERAL',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ROCK_TYPE']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ROCK_TYPE',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '.',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-dinodontosaurus',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-dinodontosaurus',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-isa',
#     'I-isa',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     ',',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '(',
#     'O',
#     ')',
#     '.',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-glossopterideas',
#     'O',
#     'I-glossopterideas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-entidade',
#     'I-entidade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-entidade',
#     'I-entidade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-entidade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-PERÍODO_GEOLÓGICO',
#     'I-PERÍODO_GEOLÓGICO',
#     'I-PERÍODO_GEOLÓGICO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-latite',
#     'I-latite',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-equivalente',
#     'I-equivalente',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-ruptura',
#     'I-ruptura',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-PERÍODO',
#     'I-PERÍODO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '.']],
#   [['O',
#     'O',
#     'B-GRUPO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     ',',
#     'O',
#     'O',
#     'B-FORMAÇÃO',
#     'I-FORMAÇÃO',
#     ',',
#     'B-FORMAÇÃO',
#     'I-FORMAÇÃO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '.',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-PAIBIANA',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-FORMAÇÃO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-MISC',
#     'I-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-localidade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-suíte',
#     'I-suíte',
#     'O',
#     'O',
#     'B-suíte',
#     'I-suíte',
#     'O',
#     'O',
#     'B-suíte',
#     'I-suíte',
#     'O',
#     'O',
#     'B-suíte',
#     'I-suíte',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-PERÍODO_GEOLÓGICO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-PERÍODO_GEOLÓGICO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-POÇO',
#     'I-POÇO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-POÇO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-coprólito',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-conchas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-matriz',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-quartzito',
#     'O',
#     'O',
#     'O',
#     'B-protólito',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-constrastantes',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neoarqueano',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-precipitação',
#     'I-precipitação',
#     'O',
#     'O',
#     'O',
#     'B-bacia',
#     'I-bacia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-identificação',
#     'O',
#     'O',
#     'O',
#     'I-identificação',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-material',
#     'I-material',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-rodovia',
#     'I-rodovia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-geologia',
#     'I-geologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geologia',
#     'I-geologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-processamento',
#     'I-processamento',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-evento',
#     'I-evento',
#     'I-evento',
#     'O',
#     'O',
#     'B-local',
#     'I-local',
#     'I-local',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-evento', 'I-evento']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-local',
#     'I-local',
#     'I-local',
#     'I-local',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-ORG',
#     'I-ORG',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-granitóides',
#     'I-granitóides',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-granitóides',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-fácies',
#     'I-fácies',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-crusta continental superior',
#     'I-crusta continental superior',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-LOC',
#     'I-LOC',
#     'O',
#     'B-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-LOC',
#     'I-LOC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-MISC',
#     'I-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-TIME',
#     'I-TIME',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-experimento',
#     'I-experimento',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-superfície',
#     'I-superfície',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-geólogo',
#     'I-geólogo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-nome',
#     'I-nome',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-supercontinente',
#     'I-supercontinente',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-laurásia',
#     'I-laurásia',
#     'O',
#     'O',
#     'B-gondwana',
#     'I-gondwana',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-genético',
#     'O',
#     'O',
#     'B-diamictito',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-glaciações',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-índice',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-paibiano',
#     'I-paibiano',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NUM', 'O', 'B-NUM']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-formação',
#     'O',
#     'O',
#     'I-formação',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-formação',
#     'O',
#     'O',
#     'I-formação',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-zircão',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-mineralogia',
#     'I-mineralogia',
#     'O',
#     'B-geologia',
#     'I-geologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-geologia',
#     'I-geologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-arenito',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-sedimentos',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-descrições',
#     'I-descrições',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-reservatório',
#     'I-reservatório',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-correções',
#     'I-correções',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-bacia',
#     'I-bacia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geologia',
#     'I-geologia',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geologia',
#     'I-geologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-ORG',
#     'O',
#     'O',
#     'I-ORG',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-camada',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-táxons',
#     'I-táxons',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-variações',
#     'I-variações',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-gênero',
#     'I-gênero',
#     'O',
#     'B-espécie',
#     'I-espécie',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-suíte',
#     'I-suíte',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-peridotitos',
#     'I-peridotitos',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-geo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-geo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-FÁCIE',
#     'I-FÁCIE',
#     'I-FÁCIE',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-PERÍODO',
#     'I-PERÍODO',
#     'O',
#     'O',
#     'B-ORGANISMO',
#     'I-ORGANISMO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentação',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-sedimentação',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-condições',
#     'I-condições',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-movimentação',
#     'I-movimentação',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-paleógeno',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-paleógeno',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ORG',
#     'I-ORG',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-DATE',
#     'I-DATE',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geológica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-geológica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geológica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geológica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-bacias', 'I-bacias', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-bacias',
#     'I-bacias',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
# ...
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geological_formation',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     ',',
#     'O',
#     'B-entalhamento',
#     'I-entalhamento',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '(',
#     'O',
#     'O',
#     'O',
#     ')',
#     '.',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-domínio',
#     'I-domínio',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     ',',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-domínio',
#     'I-domínio',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '.',
#     'O']],
#   [['O',
#     'B-associações',
#     'I-associações',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     ',',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '.',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-altimétricas',
#     'O',
#     'I-altimétricas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estado',
#     'I-estado',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contato',
#     'I-contato',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-formação_geológica',
#     'O',
#     'I-formação_geológica',
#     'O',
#     'O',
#     'B-formação_geológica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'B-formação_geológica',
#     'I-formação_geológica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-NUMBER',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-NUMBER',
#     'O',
#     'O',
#     'O',
#     'B-FACIES',
#     'O',
#     ',',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-FACIES',
#     'O',
#     ',',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-FACIES',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-ORG',
#     'I-ORG',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-MISC',
#     'I-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-MISC',
#     'I-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geologia',
#     'I-geologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-geologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-geologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-hidrologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-LOC',
#     'I-LOC',
#     'O',
#     'I-LOC',
#     'O',
#     'O',
#     'I-LOC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-MISC',
#     'I-MISC',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'B-magmaticas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'B-litologias',
#     'I-litologias',
#     'O',
#     'B-calcários',
#     'I-calcários',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-possibilidade',
#     'I-possibilidade',
#     'O',
#     'B-calcários',
#     'I-calcários',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-manto',
#     'I-manto',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-intraclastos',
#     'I-intraclastos',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-fase',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-chama',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-argilosos',
#     'I-argilosos',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-graníticas',
#     'I-graníticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-formações_geológicas',
#     'I-formações_geológicas',
#     'O',
#     'O',
#     'B-quatro',
#     'I-quatro',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-intraclastos',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-rochas_heterolíticas',
#     'I-rochas_heterolíticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-protólito',
#     'I-protólito',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-geológicas',
#     'I-geológicas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-peloides',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-peloides',
#     'I-peloides',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ROCHA',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-PROCESSO',
#     'O',
#     'I-PROCESSO',
#     'O',
#     'O',
#     'B-MATERIAL',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     ',',
#     'O',
#     ',',
#     'O',
#     'O',
#     'B-FATOR',
#     'I-FATOR',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     '.',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magma',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'I-magma',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-PROCESSO',
#     'I-PROCESSO',
#     'I-PROCESSO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-PROCESSO',
#     'I-PROCESSO',
#     'I-PROCESSO',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-arenito',
#     'I-arenito',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-níveis',
#     'I-níveis',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-FACIES',
#     'O',
#     'I-FACIES',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'I-FACIES',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-facies',
#     'I-facies',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-argilito',
#     'I-argilito',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-siltito',
#     'I-siltito',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estruturas',
#     'I-estruturas',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratificações',
#     'I-estratificações',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']]]}

# %%
golds
# Out:
# {'standard': [[['O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'I-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-procedimentoMetodologico',
#     'I-procedimentoMetodologico',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-metamorficas',
#     'O',
#     'O',
#     'B-metamorficas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estruturaGeologica',
#     'I-estruturaGeologica',
#     'I-estruturaGeologica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'I-baciaSedimentar',
#     'I-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-eon',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-eon',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'I-constituinteRochaSedimentar',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-estratigrafia',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'I-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'I-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'I-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'B-epoca',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-epoca',
#     'I-epoca',
#     'O']],
#   [['O',
#     'B-planctonico',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-metamorficas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-metamorficas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'I-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-era',
#     'O',
#     'B-era',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-metamorficas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-epoca',
#     'I-epoca',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-granulometria',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-procedimentoMetodologico',
#     'O',
#     'B-sistemaPetrolifero',
#     'I-sistemaPetrolifero',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sistemaPetrolifero',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'B-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'B-ambienteSedimentacao',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-epoca',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-baciaSedimentar',
#     'I-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-era',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-procedimentoMetodologico',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'B-era',
#     'O',
#     'O',
#     'B-eon',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'B-baciaSedimentar',
#     'I-baciaSedimentar',
#     'I-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-magmaticas', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sistemaPetrolifero',
#     'I-sistemaPetrolifero',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'I-baciaSedimentar',
#     'O',
#     'O',
#     'B-periodo',
#     'I-periodo',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'O',
#     'B-unidadeEstratigrafica',
#     'O',
#     'B-unidadeEstratigrafica',
#     'O',
#     'B-unidadeEstratigrafica',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'B-periodo',
#     'I-periodo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O']],
#   [['O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-baciaSedimentar',
#     'I-baciaSedimentar',
#     'I-baciaSedimentar',
#     'I-baciaSedimentar',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'I-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-mineral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-periodo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'O',
#     'B-era',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-epoca',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'B-ambienteSedimentacao',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-unidadeEstratigrafica',
#     'O',
#     'B-procedimentoMetodologico',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'B-era',
#     'O',
#     'O',
#     'B-eon',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-epoca', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'O',
#     'B-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'B-epoca',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-metamorficas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-era',
#     'O',
#     'B-era',
#     'O',
#     'B-era',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'I-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-epoca',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'B-era',
#     'O',
#     'O',
#     'B-eon',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-epoca',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'B-periodo',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'I-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['B-constituinteRochaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-era',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'B-era',
#     'O',
#     'O',
#     'B-eon',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-fosseis',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-era',
#     'B-periodo',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-eon',
#     'O']],
#   [['O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-mineral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-mineral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'B-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-epoca',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-granulometria',
#     'O']],
#   [['O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-era',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'I-baciaSedimentar',
#     'I-baciaSedimentar',
#     'I-baciaSedimentar',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-sistemaPetrolifero',
#     'I-sistemaPetrolifero',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'B-sedimentaresSiliciclasticas', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-idade',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-granulometria',
#     'I-granulometria',
#     'O',
#     'B-granulometria',
#     'O',
#     'O',
#     'B-estruturaSedimentar',
#     'I-estruturaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estruturaSedimentar',
#     'I-estruturaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estruturaSedimentar',
#     'I-estruturaSedimentar',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-periodo',
# ...
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'B-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geomorfologia',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'O',
#     'B-ambienteSedimentacao',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-mineral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'I-ambienteSedimentacao',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geomorfologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-geomorfologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-geomorfologia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-periodo',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-epoca',
#     'I-epoca',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-granulometria',
#     'I-granulometria',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-granulometria',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O']],
#   [['O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-metamorficas',
#     'O',
#     'O',
#     'B-metamorficas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-magmaticas',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-granulometria',
#     'O']],
#   [['O',
#     'B-baciaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-unidadeEstratigrafica',
#     'I-unidadeEstratigrafica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'I-contextoGeologicoDeBacia',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'B-contextoGeologicoDeBacia',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-granulometria',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'B-granulometria',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'B-granulometria',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estratigrafia',
#     'O',
#     'B-constituinteRochaSedimentar',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'B-estratigrafia',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-mineral',
#     'O',
#     'O',
#     'O',
#     'B-granulometria',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresCarbonaticas',
#     'I-sedimentaresCarbonaticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'I-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-fosseis',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-sedimentaresSiliciclasticas',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estruturaSedimentar',
#     'I-estruturaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estruturaSedimentar',
#     'I-estruturaSedimentar',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-estruturaGeologica',
#     'I-estruturaGeologica',
#     'I-estruturaGeologica',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']]]}

# %%
def _flatten_token_level(golds_split, preds_split):
    """
    golds_split:  ex.: [ [tags], [tags], ... ] mas no seu caso vem como [ [ [tags] ], ... ]
    preds_split:  mesmo formato
    retorna y_true_flat, y_pred_flat (listas de strings)
    """
    y_true_flat, y_pred_flat = [], []
    for g, p in zip(golds_split, preds_split):
        if g is None or p is None:
            continue
        # no seu dicionário: cada item é [tags]; então g[0] e p[0]
        g_seq = g[0]  # seu formato: [ [tags] ]
        p_seq = p[0]
        # sanitiza antes de alinhar
        g_seq = _coerce_seq(g_seq)
        p_seq = _coerce_seq(p_seq)
        n = min(len(g_seq), len(p_seq))
        if n <= 0:
            continue
        y_true_flat.extend(g_seq[:n])
        y_pred_flat.extend(p_seq[:n])
    return y_true_flat, y_pred_flat

def compute_token_metrics_for_split(golds_split, preds_split, labels=None):
    y_true, y_pred = _flatten_token_level(golds_split, preds_split)

    # define labels se não vierem
    if labels is None:
        labels = sorted({*y_true, *y_pred})

    # relatório sklearn (NÃO seqeval)
    rep = sk_classification_report(y_true, y_pred, labels=labels,
                                   output_dict=True, zero_division=0)
    p_micro, r_micro, f_micro, _ = precision_recall_fscore_support(
        y_true, y_pred, labels=labels, average='micro', zero_division=0
    )
    rep.setdefault("micro avg", {})
    rep["micro avg"].update({"precision": p_micro, "recall": r_micro, "f1-score": f_micro})

    metrics = {
        "precision_micro":    rep["micro avg"]["precision"],
        "recall_micro":       rep["micro avg"]["recall"],
        "f1_micro":           rep["micro avg"]["f1-score"],
        "precision_macro":    rep["macro avg"]["precision"],
        "recall_macro":       rep["macro avg"]["recall"],
        "f1_macro":           rep["macro avg"]["f1-score"],
        "precision_weighted": rep["weighted avg"]["precision"],
        "recall_weighted":    rep["weighted avg"]["recall"],
        "f1_weighted":        rep["weighted avg"]["f1-score"],
        "accuracy":           accuracy_score(y_true, y_pred),
        "support":            len(y_true),
        "num_labels":         len(labels),
    }
    return metrics, rep, (y_true, y_pred)

# %%
for nome in predictions.keys():
    print(nome)
# Out:
# standard
# heur_len
# heur_rare
# adversarial

# %%
from sklearn.metrics import (
    classification_report as sk_classification_report,
    accuracy_score,
    precision_recall_fscore_support,
)

# %%
_IOB_RE = re.compile(r"^[BIO]-")

def _coerce_tag_value_from_dict(d: dict) -> str:
    for key in ("tag", "label", "iob", "iob_tag", "ner", "entity", "type"):
        v = d.get(key)
        if isinstance(v, str):
            v = v.strip()
            if v == "O" or _IOB_RE.match(v):
                return v
    return "O"

# %%
def _coerce_seq(seq):
    """Converte uma sequência possivelmente heterogênea (str/dict/outros) -> lista de strings IOB/O."""
    out = []
    for t in seq:
        if isinstance(t, str):
            out.append(t if (t == "O" or _IOB_RE.match(t)) else "O")
        elif isinstance(t, dict):
            out.append(_coerce_tag_value_from_dict(t))
        else:
            out.append("O")
    return out

# %%
metrics_by_split = {}
reports_by_split = {}
y_true_all, y_pred_all = [], []

# se quiser uma lista de labels fixa (estável entre splits), passe em labels=
for nome in predictions.keys():
    m, rep, (y_true, y_pred) = compute_token_metrics_for_split(
        golds[nome], predictions[nome]
    )
    metrics_by_split[nome] = m
    reports_by_split[nome] = rep

# %%
metrics_by_split
# Out:
# {'standard': {'precision_micro': 0.8806230529595016,
#   'recall_micro': 0.8806230529595016,
#   'f1_micro': 0.8806230529595016,
#   'precision_macro': 0.0018122964067575807,
#   'recall_macro': 0.0018346749410065167,
#   'f1_macro': 0.001823417014335897,
#   'precision_weighted': 0.8698816116771317,
#   'recall_weighted': 0.8806230529595016,
#   'f1_weighted': 0.875219376519011,
#   'accuracy': 0.8806230529595016,
#   'support': 16050,
#   'num_labels': 517},
#  'heur_len': {'precision_micro': 0.8753555088413503,
#   'recall_micro': 0.8753555088413503,
#   'f1_micro': 0.8753555088413503,
#   'precision_macro': 0.002832027606990349,
#   'recall_macro': 0.0019018903540781466,
#   'f1_macro': 0.0020013635616796745,
#   'precision_weighted': 0.8698835932551098,
#   'recall_weighted': 0.8753555088413503,
#   'f1_weighted': 0.8717677188630644,
#   'accuracy': 0.8753555088413503,
#   'support': 16174,
#   'num_labels': 549},
#  'heur_rare': {'precision_micro': 0.8874964559115396,
#   'recall_micro': 0.8874964559115396,
#   'f1_micro': 0.8874964559115396,
#   'precision_macro': 0.002185139352194383,
#   'recall_macro': 0.0018559265588155315,
#   'f1_macro': 0.001884549398369851,
#   'precision_weighted': 0.882710681465417,
#   'recall_weighted': 0.8874964559115396,
#   'f1_weighted': 0.8849143551215183,
#   'accuracy': 0.8874964559115396,
#   'support': 17635,
#   'num_labels': 523},
#  'adversarial': {'precision_micro': 0.8489024510286446,
#   'recall_micro': 0.8489024510286446,
#   'f1_micro': 0.8489024510286446,
#   'precision_macro': 0.002131908807745974,
#   'recall_macro': 0.0018190440748878255,
#   'f1_macro': 0.0018235121190731808,
#   'precision_weighted': 0.807861143890086,
#   'recall_weighted': 0.8489024510286446,
#   'f1_weighted': 0.8277491666357294,
#   'accuracy': 0.8489024510286446,
#   'support': 20318,
#   'num_labels': 541}}

# %%
SAFE_MODEL = re.sub(r'[^A-Za-z0-9._-]+', '_', MODEL_KEY)  # "gemma2:9b" -> "gemma2_9b"
BASE_DIR   = Path("results") / SAFE_MODEL
DIR_METRICS = BASE_DIR / "metrics"
DIR_REPORTS = BASE_DIR / "reports"
DIR_PAIRS   = BASE_DIR / "pairs"      # gold/pred pareados por linha (jsonl)
DIR_RAW     = BASE_DIR / "raw"        # dumps completos (golds/predictions)

# %%
RUN_TAG = time.strftime("%Y%m%d-%H%M%S")

# %%
for d in (DIR_METRICS, DIR_REPORTS, DIR_PAIRS, DIR_RAW):
    d.mkdir(parents=True, exist_ok=True)

# %%
for nome in predictions.keys():
    # métricas token-level agregadas do split
    with open(DIR_METRICS / f"{nome}.metrics.json", "w", encoding="utf-8") as f:
        json.dump(metrics_by_split[nome], f, ensure_ascii=False, indent=2)

    # classification_report (dict) do split
    with open(DIR_REPORTS / f"{nome}.report.json", "w", encoding="utf-8") as f:
        json.dump(reports_by_split[nome], f, ensure_ascii=False, indent=2)

    # pares gold/pred por exemplo (jsonl: 1 linha = 1 ex)
    pairs_path = DIR_PAIRS / f"{nome}.jsonl"
    with open(pairs_path, "w", encoding="utf-8") as f:
        for i, (g, p) in enumerate(zip(golds[nome], predictions[nome])):
            if g is None or p is None:
                continue
            rec = {"idx": i, "gold": g[0], "pred": p[0]}
            f.write(json.dumps(rec, ensure_ascii=False) + "\n")

# ---- salvar agregados (opcional) ----
# dicionários completos (podem ficar grandes)
with open(DIR_RAW / f"golds.{RUN_TAG}.json", "w", encoding="utf-8") as f:
    json.dump(golds, f, ensure_ascii=False)
with open(DIR_RAW / f"predictions.{RUN_TAG}.json", "w", encoding="utf-8") as f:
    json.dump(predictions, f, ensure_ascii=False)

# %%
# report = {}
# f1_macro = {}
# precision = {}
# recall = {}
# metrics_all = {}

# bads_sets = {}

# for name, predidction in predictions.items():
#     preds = []
#     print(predidction)
#     for tags_prediction in predidction:
#         try:
#             preds.append(json.loads(tags_prediction)['tags']) 
#         except:
#             try:
#                 preds.append(json.loads(tags_prediction[0])['tags']) 
#             except:
#                 try:
#                     preds.append(json.loads(tags_prediction[0][0])['tags']) 
#                 except:
#                     preds.append(['O'])
          
#     new_preds = []
#     for pred_token in preds:
#         if type(pred_token) == str:
#             new_preds.append(pred_token)
#         else:
#             tokens_ajustados = []  
#             for token in pred_token:
#                 try:
#                     if int(_).is_integer():
#                         tokens_ajustados.extend([token_ajustado])
#                     else:
#                         tokens_ajustados.extend([token])
#                 except:
#                     try:
#                         token_ajustado = token['tag']
#                         tokens_ajustados.extend([token_ajustado])
#                     except:
#                         token_ajustado = token
#                         tokens_ajustados.extend([token_ajustado])
#             new_preds.append(tokens_ajustados)

        
#     if type(golds[name][0][0]) == list:
#         actual_golds = [gold[0] for gold in golds[name]]
#         print('ok')
#     else:
#         actual_golds = golds[name]
#     actual_preds = new_preds
#     print(new_preds)
#     # clean_golds, cleaned, clean_preds = [], [], []

#     # for i, (g, p) in enumerate(zip(actual_golds, actual_preds)):
#     #     if type(g[0][0]) == list:
#     #         g_ = g[0]
#     #         print(len(g_), len(p))
#     #         if len(p) < len(g_):
#     #             print('limpou preds'); print(i)
#     #             cleaned.append(i)
#     #             continue  # pula a adição
#     #         elif len(p) > len(g_):
#     #             print('limpou golds'); print(i)
#     #             cleaned.append(i)
#     #             continue  # pula a adição
#     #     else:
#     #         print(len(g), len(p))
#     #         if len(p) < len(g):
#     #             print('limpou preds'); print(i)
#     #             cleaned.append(i)
#     #             continue  # pula a adição
#     #         elif len(p) > len(g):
#     #             print('limpou golds'); print(i)
#     #             cleaned.append(i)
#     #             continue  # pula a adição

#     clean_golds, clean_preds = [], []
#     for g, p in zip(actual_golds, actual_preds):
#         # se o modelo gerar menos/more tags que tokens, ajustamos:
#         if type(g[0][0]) == list:
#             g_ = g[0]
#             if len(p) < len(g_):
#                 print('limpou preds')
#                 p = p + ["O"] * (len(g_) - len(p))          # completa com O
#             elif len(p) > len(g_):
#                 print('limpou golds')
#                 p = p[:len(g_)]                             # descarta excedente
#             clean_golds.append(g_)
#             clean_preds.append(p)
#         else:
#             if len(p) < len(g):
#                 print('limpou preds')
#                 p = p + ["O"] * (len(g) - len(p))          # completa com O
#             elif len(p) > len(g):
#                 print('limpou golds')
#                 p = p[:len(g)]                             # descarta excedente
#             clean_golds.append(g)
#             clean_preds.append(p)

#     # bad = set(cleaned)

#     # bads_sets[name] = bad

#     # clean_golds[:] = [g for i, g in enumerate(actual_golds) if i not in bad]
#     # clean_preds[:] = [p for i, p in enumerate(actual_preds) if i not in bad]

#     # print(f"{name}: {len(clean_golds)} exemplos válidos ({len(bad)} removidos)")
#     # print(clean_golds, len(clean_golds))
#     # print(clean_preds, len(clean_preds))
#     if len(clean_golds) != 0 and len(clean_preds) != 0:
#         report[name] = classification_report(clean_golds, clean_preds, output_dict=True)
#         f1_macro[name] = f1_score(clean_golds, clean_preds, average="macro")
#         precision[name] = precision_score(clean_golds, clean_preds, average="macro")
#         recall[name] = recall_score(clean_golds, clean_preds, average="macro")
#         rep = classification_report(clean_golds, clean_preds, scheme=IOB2, zero_division=0, output_dict=True)

#         metrics = {
#             "precision_micro":   rep["micro avg"]["precision"],
#             "recall_micro":      rep["micro avg"]["recall"],
#             "f1_micro":          rep["micro avg"]["f1-score"],
#             "precision_macro":   rep["macro avg"]["precision"],
#             "recall_macro":      rep["macro avg"]["recall"],
#             "f1_macro":          rep["macro avg"]["f1-score"],
#             "precision_weighted":rep["weighted avg"]["precision"],
#             "recall_weighted":   rep["weighted avg"]["recall"],
#             "f1_weighted":       rep["weighted avg"]["f1-score"],
#             "accuracy":          accuracy_score(clean_golds, clean_preds),
#         }

#         metrics_all[name] = metrics
# Out:
# [[['O', 'O', 'O', 'O', 'B-paleomesoproterozoico', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-paleomesoproterozoico', 'O', 'O', 'B-windley', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-megaflorísticos', 'O', 'B-carbonífera', 'O', 'O', 'O', 'O', 'I-carbonífera', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [[{'start': 12, 'end': 23, 'label': 'Bacia do Paraná'}, {'start': 47, 'end': 58, 'label': 'Formação de Mira'}, 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-evento', 'I-evento', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-grupo', 'I-grupo', 'O']], [['O', 'O', 'O', 'O', 'O', 'B-época', 'I-época', 'O', 'O', 'B-evento', 'I-evento', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'B-material', 'O', 'O', 'O', 'O', 'I-material', 'I-material', 'O', 'O', 'B-material', 'I-material', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'B-região', 'I-região', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['B-sucesso', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NUM', 'O', 'O', 'O', 'B-NUM', 'O', 'O', 'O', 'O', 'I-NUM', 'O']], [['O', 'O', 'O', 'B-NUM', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',  ...
# ok
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# [[['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ERA', 'I-ERA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']], [['O', 'B-tempo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-tempo', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-epoca', 'I-epoca', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geologia', 'I-geologia', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-LOC', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'B-DURATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'B-na2o', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-na2o', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['B-mineral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-material', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-REGIAO', 'O', 'O', 'O', 'I-REGIAO', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-acumulações', 'I-acumulações', 'O', 'O', 'O', 'O', 'O',  ...
# ok
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# c:\Users\user\Documents\mestrado\ner_splits\ner_splits\Lib\site-packages\seqeval\metrics\v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\user\Documents\mestrado\ner_splits\ner_splits\Lib\site-packages\seqeval\metrics\v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\user\Documents\mestrado\ner_splits\ner_splits\Lib\site-packages\seqeval\metrics\v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-evento', 'I-evento', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-estrutura', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-estrutura', 'I-estrutura', 'I-estrutura', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['Ocorreu', '3.6 bilhões de anos atrás', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O']], [['O', 'B-eoceno', 'I-eoceno', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'B-animais', 'I-animais', 'O', 'O', 'O', 'B-anelídeos', 'O', 'B-artrópodes', 'O', 'B-equinódermes', 'O', 'B-braquiópodes', 'O', 'B-onicóforos', 'O', 'B-esponjas', 'O', 'B-moluscos', 'I-moluscos', 'O', 'B-monoplacófiros', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-sódio', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-jazidas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-jazidas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'B-cráton', 'O', 'O', 'O', 'O', 'O', 'O', '(', 'O', ')', 'O', 'O', 'O', 'O', 'B-formação', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-formação', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-evento', 'O', 'O', 'O', 'O', 'O', 'O', 'I-evento', 'O', 'O', 'O', 'O', '.']], [['O', 'B-autor', 'O', 'O', 'I-autor', 'O', 'O', 'I-autor', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-autor', 'O', 'O', 'O', 'O', '.', 'O', 'O']], [['O', 'B-conglomerado', 'O', 'O', 'I-conglomerado', 'O', 'O', 'O', 'O', 'O', 'O', 'O', '.', 'O']], [['O', 'B-DATA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'B-EVENT', 'B-EVENT', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', ...
# ok
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# [[['O', 'B-magmaticas', 'I-magmaticas', 'O', 'O', 'B-magmaticas', 'I-magmaticas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-magmaticas', 'I-magmaticas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'B-magmaticas', 'I-magmaticas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-idade', 'I-idade', 'O', 'B-idade', 'I-idade', 'O', 'O', 'O', 'B-idade', 'I-idade', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-idade', 'I-idade', 'O', 'B-idade', 'I-idade', 'O', 'O', 'O', 'B-idade', 'I-idade', 'O', 'O', 'B-idade', 'I-idade', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-idade', 'I-idade', 'O', 'B-idade', 'I-idade', 'O', 'O', 'O', 'B-idade', 'I-idade', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'B-PERÍODO', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PERÍODO', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERÍODO', 'O', 'O', 'O', 'O', 'O', 'O', 'I-PERÍODO', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-magmáticas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'B-PERÍODO', 'I-PERÍODO', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-TEMPO', 'I-TEMPO', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'B-era', 'I-era', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-vulcanismo', 'I-vulcanismo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATA', 'I-DATA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATA', 'I-DATA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-Paleogenico', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Mamiferos', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Mamiferos', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Paleogenico', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-paleogênico', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-animais', 'I-animais', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-mamíferos', 'I-mamíferos', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-paleozóica', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-paleógeno', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-animais', 'I-animais', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-PERÍODO', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ERA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'B-ERA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# ok
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds
# limpou preds

# %%
# precision_micro = []
# recall_micro = []
# f1_micro = []
# f1_macro = []
# precision_macro = []
# recall_macro = []
# f1_weighted = []
# precision_weighted = []
# recall_weighted = []
# accuracy = []
# name = []

# for keys,value in metrics_all.items():
#     name.append(keys)
#     precision_micro.append(value['precision_micro'])
#     recall_micro.append(value['recall_micro'])
#     f1_micro.append(value['f1_micro'])
#     precision_macro.append(value['precision_macro'])
#     recall_macro.append(value['recall_macro'])
#     f1_macro.append(value['f1_macro'])
#     precision_weighted.append(value['precision_weighted'])
#     recall_weighted.append(value['recall_weighted'])
#     f1_weighted.append(value['f1_weighted'])
#     accuracy.append(value['accuracy'])

# df_results = pd.DataFrame({'name':name,
#                            'precision_micro':precision_micro,
#                            'recall_micro':recall_micro,
#                            'f1_micro':f1_micro,
#                            'precision_macro':precision_macro,
#                            'recall_macro':recall_macro,
#                            'f1_macro':f1_macro,
#                            'precision_weighted':precision_weighted,
#                            'recall_weighted':recall_weighted,
#                            'f1_weighted':f1_weighted,
#                            'accuracy':accuracy})

# %%
# df_results.to_csv(f'metricas_{model_escolhido.replace(':', '')}_exclusao.csv', index=False)

# %%
# report = {}
# f1_macro = {}
# precision = {}
# recall = {}
# metrics_all2 = {}

# bads_sets = {}

# for name, predidction in predictions.items():
#     preds = []
#     print(predidction)
#     for tags_prediction in predidction:
#         try:
#             preds.append(json.loads(tags_prediction)['tags']) 
#         except:
#             try:
#                 preds.append(json.loads(tags_prediction[0])['tags']) 
#             except:
#                 try:
#                     preds.append(json.loads(tags_prediction[0][0])['tags']) 
#                 except:
#                     preds.append(['O'])
          
#     new_preds = []
#     for pred_token in preds:
#         if type(pred_token) == str:
#             new_preds.append(pred_token)
#         else:
#             tokens_ajustados = []  
#             for token in pred_token:
#                 try:
#                     if int(_).is_integer():
#                         tokens_ajustados.extend([token_ajustado])
#                     else:
#                         tokens_ajustados.extend([token])
#                 except:
#                     try:
#                         token_ajustado = token['tag']
#                         tokens_ajustados.extend([token_ajustado])
#                     except:
#                         token_ajustado = token
#                         tokens_ajustados.extend([token_ajustado])
#             new_preds.append(tokens_ajustados)

        
#     if type(golds[name][0][0]) == list:
#         actual_golds = [gold[0] for gold in golds[name]]
#         print('ok')
#     else:
#         actual_golds = golds[name]
#     actual_preds = new_preds
#     print(new_preds)
#     clean_golds, cleaned, clean_preds = [], [], []

#     for i, (g, p) in enumerate(zip(actual_golds, actual_preds)):
#         if type(g[0][0]) == list:
#             g_ = g[0]
#             print(len(g_), len(p))
#             if len(p) < len(g_):
#                 print('limpou preds'); print(i)
#                 cleaned.append(i)
#                 continue  # pula a adição
#             elif len(p) > len(g_):
#                 print('limpou golds'); print(i)
#                 cleaned.append(i)
#                 continue  # pula a adição
#         else:
#             print(len(g), len(p))
#             if len(p) < len(g):
#                 print('limpou preds'); print(i)
#                 cleaned.append(i)
#                 continue  # pula a adição
#             elif len(p) > len(g):
#                 print('limpou golds'); print(i)
#                 cleaned.append(i)
#                 continue  # pula a adição

#     bad = set(cleaned)

#     bads_sets[name] = bad

#     clean_golds[:] = [g for i, g in enumerate(actual_golds) if i not in bad]
#     clean_preds[:] = [p for i, p in enumerate(actual_preds) if i not in bad]


#     if len(clean_golds) != 0 and len(clean_preds) != 0:
#         report[name] = classification_report(clean_golds, clean_preds, output_dict=True)
#         f1_macro[name] = f1_score(clean_golds, clean_preds, average="macro")
#         precision[name] = precision_score(clean_golds, clean_preds, average="macro")
#         recall[name] = recall_score(clean_golds, clean_preds, average="macro")

#         rep = classification_report(clean_golds, clean_preds, scheme=IOB2, zero_division=0, output_dict=True)
        
#         metrics2 = {
#             "precision_micro":   rep["micro avg"]["precision"],
#             "recall_micro":      rep["micro avg"]["recall"],
#             "f1_micro":          rep["micro avg"]["f1-score"],
#             "precision_macro":   rep["macro avg"]["precision"],
#             "recall_macro":      rep["macro avg"]["recall"],
#             "f1_macro":          rep["macro avg"]["f1-score"],
#             "precision_weighted":rep["weighted avg"]["precision"],
#             "recall_weighted":   rep["weighted avg"]["recall"],
#             "f1_weighted":       rep["weighted avg"]["f1-score"],
#             "accuracy":          accuracy_score(clean_golds, clean_preds),
#         }

#         metrics_all2[name] = metrics2
# Out:
# [[['O', 'O', 'O', 'O', 'B-paleomesoproterozoico', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-paleomesoproterozoico', 'O', 'O', 'B-windley', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-megaflorísticos', 'O', 'B-carbonífera', 'O', 'O', 'O', 'O', 'I-carbonífera', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [[{'start': 12, 'end': 23, 'label': 'Bacia do Paraná'}, {'start': 47, 'end': 58, 'label': 'Formação de Mira'}, 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-evento', 'I-evento', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-grupo', 'I-grupo', 'O']], [['O', 'O', 'O', 'O', 'O', 'B-época', 'I-época', 'O', 'O', 'B-evento', 'I-evento', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'B-material', 'O', 'O', 'O', 'O', 'I-material', 'I-material', 'O', 'O', 'B-material', 'I-material', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'B-região', 'I-região', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['B-sucesso', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NUM', 'O', 'O', 'O', 'B-NUM', 'O', 'O', 'O', 'O', 'I-NUM', 'O']], [['O', 'O', 'O', 'B-NUM', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',  ...
# ok
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# 35 1
# limpou preds
# 0
# 45 1
# limpou preds
# 1
# 60 1
# limpou preds
# 2
# 56 1
# limpou preds
# 3
# 13 1
# limpou preds
# 4
# 28 1
# limpou preds
# 5
# 46 1
# limpou preds
# 6
# 34 1
# limpou preds
# 7
# 27 1
# limpou preds
# 8
# 44 1
# limpou preds
# 9
# 19 1
# limpou preds
# 10
# 5 1
# limpou preds
# 11
# 42 1
# limpou preds
# 12
# 38 1
# limpou preds
# 13
# 32 1
# limpou preds
# 14
# 32 1
# limpou preds
# 15
# 41 1
# limpou preds
# 16
# 24 1
# limpou preds
# 17
# 5 1
# limpou preds
# 18
# 9 1
# limpou preds
# 19
# 16 1
# limpou preds
# 20
# 33 1
# limpou preds
# 21
# 31 1
# limpou preds
# 22
# 38 1
# limpou preds
# 23
# 44 1
# limpou preds
# 24
# 37 1
# limpou preds
# 25
# 34 1
# limpou preds
# 26
# 54 1
# limpou preds
# 27
# 43 1
# limpou preds
# 28
# 38 1
# limpou preds
# 29
# 36 1
# limpou preds
# 30
# 18 1
# limpou preds
# 31
# 29 1
# limpou preds
# 32
# 64 1
# limpou preds
# 33
# 35 1
# limpou preds
# 34
# 41 1
# limpou preds
# 35
# 17 1
# limpou preds
# 36
# 14 1
# limpou preds
# 37
# 35 1
# limpou preds
# 38
# 16 1
# limpou preds
# 39
# 43 1
# limpou preds
# 40
# 57 1
# limpou preds
# 41
# 14 1
# limpou preds
# 42
# 104 1
# limpou preds
# 43
# 91 1
# limpou preds
# 44
# 20 1
# limpou preds
# 45
# 31 1
# limpou preds
# 46
# 44 1
# limpou preds
# 47
# 22 1
# limpou preds
# 48
# 23 1
# limpou preds
# 49
# 18 1
# limpou preds
# 50
# 21 1
# limpou preds
# 51
# 19 1
# limpou preds
# 52
# 45 1
# limpou preds
# 53
# 19 1
# limpou preds
# 54
# 34 1
# limpou preds
# 55
# 22 1
# limpou preds
# 56
# 25 1
# limpou preds
# 57
# 4 1
# limpou preds
# 58
# 28 1
# limpou preds
# 59
# 22 1
# limpou preds
# 60
# 85 1
# limpou preds
# 61
# 11 1
# limpou preds
# 62
# 58 1
# limpou preds
# 63
# 27 1
# limpou preds
# 64
# 18 1
# limpou preds
# 65
# 18 1
# limpou preds
# 66
# 59 1
# limpou preds
# 67
# 26 1
# limpou preds
# 68
# 15 1
# limpou preds
# 69
# 33 1
# limpou preds
# 70
# 19 1
# limpou preds
# 71
# 34 1
# limpou preds
# 72
# 28 1
# limpou preds
# 73
# 36 1
# limpou preds
# 74
# 16 1
# limpou preds
# 75
# 33 1
# limpou preds
# 76
# 30 1
# limpou preds
# 77
# 25 1
# limpou preds
# 78
# 58 1
# limpou preds
# 79
# 43 1
# limpou preds
# 80
# 60 1
# limpou preds
# 81
# 3 1
# limpou preds
# 82
# 27 1
# limpou preds
# 83
# 34 1
# limpou preds
# 84
# 31 1
# limpou preds
# 85
# 42 1
# limpou preds
# 86
# 26 1
# limpou preds
# 87
# 23 1
# limpou preds
# 88
# 29 1
# limpou preds
# 89
# 42 1
# limpou preds
# 90
# 10 1
# limpou preds
# 91
# 37 1
# limpou preds
# 92
# 32 1
# limpou preds
# 93
# 31 1
# limpou preds
# 94
# 21 1
# limpou preds
# 95
# 23 1
# limpou preds
# 96
# 32 1
# limpou preds
# 97
# 11 1
# limpou preds
# 98
# 49 1
# limpou preds
# 99
# 40 1
# limpou preds
# 100
# 31 1
# limpou preds
# 101
# 32 1
# limpou preds
# 102
# 33 1
# limpou preds
# 103
# 15 1
# limpou preds
# 104
# 20 1
# limpou preds
# 105
# 6 1
# limpou preds
# 106
# 7 1
# limpou preds
# 107
# 32 1
# limpou preds
# 108
# 37 1
# limpou preds
# 109
# 24 1
# limpou preds
# 110
# 45 1
# limpou preds
# 111
# 28 1
# limpou preds
# 112
# 19 1
# limpou preds
# 113
# 34 1
# limpou preds
# 114
# 39 1
# limpou preds
# 115
# 46 1
# limpou preds
# 116
# 52 1
# limpou preds
# 117
# 18 1
# limpou preds
# 118
# 16 1
# limpou preds
# 119
# 19 1
# limpou preds
# 120
# 20 1
# limpou preds
# 121
# 13 1
# limpou preds
# 122
# 23 1
# limpou preds
# 123
# 38 1
# limpou preds
# 124
# 26 1
# limpou preds
# 125
# 21 1
# limpou preds
# 126
# 20 1
# limpou preds
# 127
# 45 1
# limpou preds
# 128
# 24 1
# limpou preds
# 129
# 19 1
# limpou preds
# 130
# 23 1
# limpou preds
# 131
# 33 1
# limpou preds
# 132
# 46 1
# limpou preds
# 133
# 40 1
# limpou preds
# 134
# 20 1
# limpou preds
# 135
# 20 1
# limpou preds
# 136
# 8 1
# limpou preds
# 137
# 44 1
# limpou preds
# 138
# 16 1
# limpou preds
# 139
# 16 1
# limpou preds
# 140
# 65 1
# limpou preds
# 141
# 48 1
# limpou preds
# 142
# 31 1
# limpou preds
# 143
# 79 1
# limpou preds
# 144
# 38 1
# limpou preds
# 145
# 22 1
# limpou preds
# 146
# 26 1
# limpou preds
# 147
# 31 1
# limpou preds
# 148
# 52 1
# limpou preds
# 149
# 21 1
# limpou preds
# 150
# 13 1
# limpou preds
# 151
# 44 1
# limpou preds
# 152
# 27 1
# limpou preds
# 153
# 14 1
# limpou preds
# 154
# 28 1
# limpou preds
# 155
# 58 1
# limpou preds
# 156
# 26 1
# limpou preds
# 157
# 32 1
# limpou preds
# 158
# 24 1
# limpou preds
# 159
# 12 1
# limpou preds
# 160
# 74 1
# limpou preds
# 161
# 33 1
# limpou preds
# 162
# 21 1
# limpou preds
# 163
# 43 1
# limpou preds
# 164
# 34 1
# limpou preds
# 165
# 18 1
# limpou preds
# 166
# 64 1
# limpou preds
# 167
# 28 1
# limpou preds
# 168
# 17 1
# limpou preds
# 169
# 33 1
# limpou preds
# 170
# 49 1
# limpou preds
# 171
# 35 1
# limpou preds
# 172
# 22 1
# limpou preds
# 173
# 106 1
# limpou preds
# 174
# 30 1
# limpou preds
# 175
# 11 1
# limpou preds
# 176
# 14 1
# limpou preds
# 177
# 28 1
# limpou preds
# 178
# 15 1
# limpou preds
# 179
# 27 1
# limpou preds
# 180
# 14 1
# limpou preds
# 181
# 47 1
# limpou preds
# 182
# 28 1
# limpou preds
# 183
# 9 1
# limpou preds
# 184
# 27 1
# limpou preds
# 185
# 50 1
# limpou preds
# 186
# 32 1
# limpou preds
# 187
# 63 1
# limpou preds
# 188
# 36 1
# limpou preds
# 189
# 57 1
# limpou preds
# 190
# 29 1
# limpou preds
# 191
# 40 1
# limpou preds
# 192
# 18 1
# limpou preds
# 193
# 29 1
# limpou preds
# 194
# 28 1
# limpou preds
# 195
# 72 1
# limpou preds
# 196
# 42 1
# limpou preds
# 197
# 29 1
# limpou preds
# 198
# 19 1
# limpou preds
# 199
# 57 1
# limpou preds
# 200
# 61 1
# limpou preds
# 201
# 24 1
# limpou preds
# 202
# 24 1
# limpou preds
# 203
# 16 1
# limpou preds
# 204
# 10 1
# limpou preds
# 205
# 39 1
# limpou preds
# 206
# 12 1
# limpou preds
# 207
# 34 1
# limpou preds
# 208
# 29 1
# limpou preds
# 209
# 57 1
# limpou preds
# 210
# 28 1
# limpou preds
# 211
# 29 1
# limpou preds
# 212
# 43 1
# limpou preds
# 213
# 34 1
# limpou preds
# 214
# 35 1
# limpou preds
# 215
# 165 1
# limpou preds
# 216
# 27 1
# limpou preds
# 217
# 24 1
# limpou preds
# 218
# 28 1
# limpou preds
# 219
# 52 1
# limpou preds
# 220
# 34 1
# limpou preds
# 221
# 19 1
# limpou preds
# 222
# 30 1
# limpou preds
# 223
# 21 1
# limpou preds
# 224
# 45 1
# limpou preds
# 225
# 41 1
# limpou preds
# 226
# 32 1
# limpou preds
# 227
# 23 1
# limpou preds
# 228
# 34 1
# limpou preds
# 229
# 23 1
# limpou preds
# 230
# 27 1
# limpou preds
# 231
# 78 1
# limpou preds
# 232
# 37 1
# limpou preds
# 233
# 36 1
# limpou preds
# 234
# 27 1
# limpou preds
# 235
# 56 1
# limpou preds
# 236
# 36 1
# limpou preds
# 237
# 10 1
# limpou preds
# 238
# 82 1
# limpou preds
# 239
# 20 1
# limpou preds
# 240
# 21 1
# limpou preds
# 241
# 14 1
# limpou preds
# 242
# 19 1
# limpou preds
# 243
# 40 1
# limpou preds
# 244
# 26 1
# limpou preds
# 245
# 38 1
# limpou preds
# 246
# 33 1
# limpou preds
# 247
# 41 1
# limpou preds
# 248
# 31 1
# limpou preds
# 249
# 19 1
# limpou preds
# 250
# 61 1
# limpou preds
# 251
# 25 1
# limpou preds
# 252
# 19 1
# limpou preds
# 253
# 52 1
# limpou preds
# 254
# 35 1
# limpou preds
# 255
# 27 1
# limpou preds
# 256
# 21 1
# limpou preds
# 257
# 28 1
# limpou preds
# 258
# 29 1
# limpou preds
# 259
# 41 1
# limpou preds
# 260
# 46 1
# limpou preds
# 261
# 27 1
# limpou preds
# 262
# 18 1
# limpou preds
# 263
# 21 1
# limpou preds
# 264
# 20 1
# limpou preds
# 265
# 41 1
# limpou preds
# 266
# 19 1
# limpou preds
# 267
# 44 1
# limpou preds
# 268
# 77 1
# limpou preds
# 269
# 51 1
# limpou preds
# 270
# 32 1
# limpou preds
# 271
# 32 1
# limpou preds
# 272
# 56 1
# limpou preds
# 273
# 16 1
# limpou preds
# 274
# 25 1
# limpou preds
# 275
# 30 1
# limpou preds
# 276
# 23 1
# limpou preds
# 277
# 20 1
# limpou preds
# 278
# 48 1
# limpou preds
# 279
# 15 1
# limpou preds
# 280
# 48 1
# limpou preds
# 281
# 8 1
# limpou preds
# 282
# 102 1
# limpou preds
# 283
# 28 1
# limpou preds
# 284
# 34 1
# limpou preds
# 285
# 36 1
# limpou preds
# 286
# 16 1
# limpou preds
# 287
# 49 1
# limpou preds
# 288
# 25 1
# limpou preds
# 289
# 26 1
# limpou preds
# 290
# 22 1
# limpou preds
# 291
# 36 1
# limpou preds
# 292
# 8 1
# limpou preds
# 293
# 21 1
# limpou preds
# 294
# 11 1
# limpou preds
# 295
# 52 1
# limpou preds
# 296
# 38 1
# limpou preds
# 297
# 45 1
# limpou preds
# 298
# 37 1
# limpou preds
# 299
# 19 1
# limpou preds
# 300
# 24 1
# limpou preds
# 301
# 37 1
# limpou preds
# 302
# 44 1
# limpou preds
# 303
# 34 1
# limpou preds
# 304
# 15 1
# limpou preds
# 305
# 10 1
# limpou preds
# 306
# 19 1
# limpou preds
# 307
# 20 1
# limpou preds
# 308
# 17 1
# limpou preds
# 309
# 57 1
# limpou preds
# 310
# 8 1
# limpou preds
# 311
# 27 1
# limpou preds
# 312
# 26 1
# limpou preds
# 313
# 62 1
# limpou preds
# 314
# 171 1
# limpou preds
# 315
# 21 1
# limpou preds
# 316
# 8 1
# limpou preds
# 317
# 22 1
# limpou preds
# 318
# 34 1
# limpou preds
# 319
# 14 1
# limpou preds
# 320
# 22 1
# limpou preds
# 321
# 36 1
# limpou preds
# 322
# 23 1
# limpou preds
# 323
# 31 1
# limpou preds
# 324
# 13 1
# limpou preds
# 325
# 30 1
# limpou preds
# 326
# 34 1
# limpou preds
# 327
# 39 1
# limpou preds
# 328
# 26 1
# limpou preds
# 329
# 29 1
# limpou preds
# 330
# 21 1
# limpou preds
# 331
# 24 1
# limpou preds
# 332
# 40 1
# limpou preds
# 333
# 22 1
# limpou preds
# 334
# 33 1
# limpou preds
# 335
# 11 1
# limpou preds
# 336
# 87 1
# limpou preds
# 337
# 26 1
# limpou preds
# 338
# 27 1
# limpou preds
# 339
# 24 1
# limpou preds
# 340
# 27 1
# limpou preds
# 341
# 18 1
# limpou preds
# 342
# 20 1
# limpou preds
# 343
# 31 1
# limpou preds
# 344
# 25 1
# limpou preds
# 345
# 19 1
# limpou preds
# 346
# 21 1
# limpou preds
# 347
# 22 1
# limpou preds
# 348
# 28 1
# limpou preds
# 349
# 14 1
# limpou preds
# 350
# 29 1
# limpou preds
# 351
# 39 1
# limpou preds
# 352
# 54 1
# limpou preds
# 353
# 36 1
# limpou preds
# 354
# 39 1
# limpou preds
# 355
# 33 1
# limpou preds
# 356
# 38 1
# limpou preds
# 357
# 23 1
# limpou preds
# 358
# 25 1
# limpou preds
# 359
# 40 1
# limpou preds
# 360
# 36 1
# limpou preds
# 361
# 25 1
# limpou preds
# 362
# 27 1
# limpou preds
# 363
# 35 1
# limpou preds
# 364
# 16 1
# limpou preds
# 365
# 20 1
# limpou preds
# 366
# 17 1
# limpou preds
# 367
# 26 1
# limpou preds
# 368
# 47 1
# limpou preds
# 369
# 39 1
# limpou preds
# 370
# 13 1
# limpou preds
# 371
# 10 1
# limpou preds
# 372
# 32 1
# limpou preds
# 373
# 37 1
# limpou preds
# 374
# 19 1
# limpou preds
# 375
# 46 1
# limpou preds
# 376
# 20 1
# limpou preds
# 377
# 110 1
# limpou preds
# 378
# 46 1
# limpou preds
# 379
# 55 1
# limpou preds
# 380
# 14 1
# limpou preds
# 381
# 17 1
# limpou preds
# 382
# 18 1
# limpou preds
# 383
# 21 1
# limpou preds
# 384
# 19 1
# limpou preds
# 385
# 17 1
# limpou preds
# 386
# 16 1
# limpou preds
# 387
# 41 1
# limpou preds
# 388
# 15 1
# limpou preds
# 389
# 56 1
# limpou preds
# 390
# 54 1
# limpou preds
# 391
# 22 1
# limpou preds
# 392
# 33 1
# limpou preds
# 393
# 19 1
# limpou preds
# 394
# 21 1
# limpou preds
# 395
# 31 1
# limpou preds
# 396
# 16 1
# limpou preds
# 397
# 69 1
# limpou preds
# 398
# 23 1
# limpou preds
# 399
# 45 1
# limpou preds
# 400
# 34 1
# limpou preds
# 401
# 47 1
# limpou preds
# 402
# 65 1
# limpou preds
# 403
# 62 1
# limpou preds
# 404
# 40 1
# limpou preds
# 405
# 8 1
# limpou preds
# 406
# 26 1
# limpou preds
# 407
# 12 1
# limpou preds
# 408
# 24 1
# limpou preds
# 409
# 57 1
# limpou preds
# 410
# 19 1
# limpou preds
# 411
# 48 1
# limpou preds
# 412
# 34 1
# limpou preds
# 413
# 21 1
# limpou preds
# 414
# 54 1
# limpou preds
# 415
# 27 1
# limpou preds
# 416
# 28 1
# limpou preds
# 417
# 30 1
# limpou preds
# 418
# 34 1
# limpou preds
# 419
# 19 1
# limpou preds
# 420
# 23 1
# limpou preds
# 421
# 26 1
# limpou preds
# 422
# 95 1
# limpou preds
# 423
# 43 1
# limpou preds
# 424
# 53 1
# limpou preds
# 425
# 16 1
# limpou preds
# 426
# 30 1
# limpou preds
# 427
# 35 1
# limpou preds
# 428
# 41 1
# limpou preds
# 429
# 35 1
# limpou preds
# 430
# 31 1
# limpou preds
# 431
# 8 1
# limpou preds
# 432
# 27 1
# limpou preds
# 433
# 26 1
# limpou preds
# 434
# 33 1
# limpou preds
# 435
# 64 1
# limpou preds
# 436
# 18 1
# limpou preds
# 437
# 19 1
# limpou preds
# 438
# 8 1
# limpou preds
# 439
# 34 1
# limpou preds
# 440
# 40 1
# limpou preds
# 441
# 29 1
# limpou preds
# 442
# 35 1
# limpou preds
# 443
# 19 1
# limpou preds
# 444
# 25 1
# limpou preds
# 445
# 21 1
# limpou preds
# 446
# 66 1
# limpou preds
# 447
# 11 1
# limpou preds
# 448
# 20 1
# limpou preds
# 449
# 36 1
# limpou preds
# 450
# 5 1
# limpou preds
# 451
# 39 1
# limpou preds
# 452
# 52 1
# limpou preds
# 453
# 18 1
# limpou preds
# 454
# 43 1
# limpou preds
# 455
# 15 1
# limpou preds
# 456
# 58 1
# limpou preds
# 457
# 40 1
# limpou preds
# 458
# 20 1
# limpou preds
# 459
# 39 1
# limpou preds
# 460
# 24 1
# limpou preds
# 461
# 46 1
# limpou preds
# 462
# 38 1
# limpou preds
# 463
# 40 1
# limpou preds
# 464
# 27 1
# limpou preds
# 465
# 41 1
# limpou preds
# 466
# 34 1
# limpou preds
# 467
# 30 1
# limpou preds
# 468
# 17 1
# limpou preds
# 469
# 23 1
# limpou preds
# 470
# 30 1
# limpou preds
# 471
# 15 1
# limpou preds
# 472
# 34 1
# limpou preds
# 473
# 40 1
# limpou preds
# 474
# 9 1
# limpou preds
# 475
# 16 1
# limpou preds
# 476
# 25 1
# limpou preds
# 477
# 18 1
# limpou preds
# 478
# 27 1
# limpou preds
# 479
# 21 1
# limpou preds
# 480
# 47 1
# limpou preds
# 481
# 26 1
# limpou preds
# 482
# 9 1
# limpou preds
# 483
# 18 1
# limpou preds
# 484
# 27 1
# limpou preds
# 485
# 27 1
# limpou preds
# 486
# 2 1
# limpou preds
# 487
# 37 1
# limpou preds
# 488
# 52 1
# limpou preds
# 489
# 36 1
# limpou preds
# 490
# 26 1
# limpou preds
# 491
# 60 1
# limpou preds
# 492
# 43 1
# limpou preds
# 493
# 18 1
# limpou preds
# 494
# 18 1
# limpou preds
# 495
# 18 1
# limpou preds
# 496
# 11 1
# limpou preds
# 497
# 15 1
# limpou preds
# 498
# 28 1
# limpou preds
# 499
# [[['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ERA', 'I-ERA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'I-LOC', 'O']], [['O', 'B-tempo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-tempo', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-geo', 'I-geo', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-epoca', 'I-epoca', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-geologia', 'I-geologia', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-LOC', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'B-DURATION', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'B-na2o', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-na2o', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['B-mineral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-material', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-REGIAO', 'O', 'O', 'O', 'I-REGIAO', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-acumulações', 'I-acumulações', 'O', 'O', 'O', 'O', 'O',  ...
# ok
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# 43 1
# limpou preds
# 0
# 31 1
# limpou preds
# 1
# 14 1
# limpou preds
# 2
# 22 1
# limpou preds
# 3
# 25 1
# limpou preds
# 4
# 86 1
# limpou preds
# 5
# 42 1
# limpou preds
# 6
# 17 1
# limpou preds
# 7
# 39 1
# limpou preds
# 8
# 20 1
# limpou preds
# 9
# 33 1
# limpou preds
# 10
# 31 1
# limpou preds
# 11
# 24 1
# limpou preds
# 12
# 34 1
# limpou preds
# 13
# 41 1
# limpou preds
# 14
# 78 1
# limpou preds
# 15
# 18 1
# limpou preds
# 16
# 19 1
# limpou preds
# 17
# 33 1
# limpou preds
# 18
# 46 1
# limpou preds
# 19
# 43 1
# limpou preds
# 20
# 40 1
# limpou preds
# 21
# 63 1
# limpou preds
# 22
# 8 1
# limpou preds
# 23
# 53 1
# limpou preds
# 24
# 63 1
# limpou preds
# 25
# 15 1
# limpou preds
# 26
# 26 1
# limpou preds
# 27
# 15 1
# limpou preds
# 28
# 34 1
# limpou preds
# 29
# 31 1
# limpou preds
# 30
# 24 1
# limpou preds
# 31
# 37 1
# limpou preds
# 32
# 42 1
# limpou preds
# 33
# 14 1
# limpou preds
# 34
# 28 1
# limpou preds
# 35
# 15 1
# limpou preds
# 36
# 31 1
# limpou preds
# 37
# 17 1
# limpou preds
# 38
# 11 1
# limpou preds
# 39
# 33 1
# limpou preds
# 40
# 57 1
# limpou preds
# 41
# 17 1
# limpou preds
# 42
# 25 1
# limpou preds
# 43
# 106 1
# limpou preds
# 44
# 17 1
# limpou preds
# 45
# 5 1
# limpou preds
# 46
# 41 1
# limpou preds
# 47
# 57 1
# limpou preds
# 48
# 26 1
# limpou preds
# 49
# 33 1
# limpou preds
# 50
# 15 1
# limpou preds
# 51
# 16 1
# limpou preds
# 52
# 44 1
# limpou preds
# 53
# 28 1
# limpou preds
# 54
# 38 1
# limpou preds
# 55
# 21 1
# limpou preds
# 56
# 34 1
# limpou preds
# 57
# 17 1
# limpou preds
# 58
# 23 1
# limpou preds
# 59
# 28 1
# limpou preds
# 60
# 32 1
# limpou preds
# 61
# 40 1
# limpou preds
# 62
# 24 1
# limpou preds
# 63
# 27 1
# limpou preds
# 64
# 31 1
# limpou preds
# 65
# 17 1
# limpou preds
# 66
# 2 1
# limpou preds
# 67
# 39 1
# limpou preds
# 68
# 34 1
# limpou preds
# 69
# 27 1
# limpou preds
# 70
# 12 1
# limpou preds
# 71
# 27 1
# limpou preds
# 72
# 44 1
# limpou preds
# 73
# 49 1
# limpou preds
# 74
# 21 1
# limpou preds
# 75
# 21 1
# limpou preds
# 76
# 35 1
# limpou preds
# 77
# 16 1
# limpou preds
# 78
# 20 1
# limpou preds
# 79
# 56 1
# limpou preds
# 80
# 20 1
# limpou preds
# 81
# 32 1
# limpou preds
# 82
# 34 1
# limpou preds
# 83
# 15 1
# limpou preds
# 84
# 18 1
# limpou preds
# 85
# 39 1
# limpou preds
# 86
# 21 1
# limpou preds
# 87
# 29 1
# limpou preds
# 88
# 13 1
# limpou preds
# 89
# 34 1
# limpou preds
# 90
# 32 1
# limpou preds
# 91
# 32 1
# limpou preds
# 92
# 35 1
# limpou preds
# 93
# 30 1
# limpou preds
# 94
# 31 1
# limpou preds
# 95
# 20 1
# limpou preds
# 96
# 49 1
# limpou preds
# 97
# 52 1
# limpou preds
# 98
# 21 1
# limpou preds
# 99
# 50 1
# limpou preds
# 100
# 51 1
# limpou preds
# 101
# 23 1
# limpou preds
# 102
# 23 1
# limpou preds
# 103
# 2 1
# limpou preds
# 104
# 23 1
# limpou preds
# 105
# 27 1
# limpou preds
# 106
# 31 1
# limpou preds
# 107
# 48 1
# limpou preds
# 108
# 62 1
# limpou preds
# 109
# 32 1
# limpou preds
# 110
# 43 1
# limpou preds
# 111
# 38 1
# limpou preds
# 112
# 36 1
# limpou preds
# 113
# 44 1
# limpou preds
# 114
# 35 1
# limpou preds
# 115
# 34 1
# limpou preds
# 116
# 34 1
# limpou preds
# 117
# 50 1
# limpou preds
# 118
# 26 1
# limpou preds
# 119
# 13 1
# limpou preds
# 120
# 27 1
# limpou preds
# 121
# 19 1
# limpou preds
# 122
# 42 1
# limpou preds
# 123
# 34 1
# limpou preds
# 124
# 31 1
# limpou preds
# 125
# 47 1
# limpou preds
# 126
# 23 1
# limpou preds
# 127
# 24 1
# limpou preds
# 128
# 28 1
# limpou preds
# 129
# 21 1
# limpou preds
# 130
# 22 1
# limpou preds
# 131
# 30 1
# limpou preds
# 132
# 33 1
# limpou preds
# 133
# 17 1
# limpou preds
# 134
# 55 1
# limpou preds
# 135
# 14 1
# limpou preds
# 136
# 34 1
# limpou preds
# 137
# 31 1
# limpou preds
# 138
# 24 1
# limpou preds
# 139
# 12 1
# limpou preds
# 140
# 14 1
# limpou preds
# 141
# 20 1
# limpou preds
# 142
# 36 1
# limpou preds
# 143
# 24 1
# limpou preds
# 144
# 38 1
# limpou preds
# 145
# 83 1
# limpou preds
# 146
# 23 1
# limpou preds
# 147
# 47 1
# limpou preds
# 148
# 32 1
# limpou preds
# 149
# 19 1
# limpou preds
# 150
# 20 1
# limpou preds
# 151
# 44 1
# limpou preds
# 152
# 19 1
# limpou preds
# 153
# 36 1
# limpou preds
# 154
# 21 1
# limpou preds
# 155
# 19 1
# limpou preds
# 156
# 47 1
# limpou preds
# 157
# 38 1
# limpou preds
# 158
# 3 1
# limpou preds
# 159
# 8 1
# limpou preds
# 160
# 44 1
# limpou preds
# 161
# 11 1
# limpou preds
# 162
# 40 1
# limpou preds
# 163
# 36 1
# limpou preds
# 164
# 30 1
# limpou preds
# 165
# 33 1
# limpou preds
# 166
# 22 1
# limpou preds
# 167
# 42 1
# limpou preds
# 168
# 12 1
# limpou preds
# 169
# 37 1
# limpou preds
# 170
# 25 1
# limpou preds
# 171
# 28 1
# limpou preds
# 172
# 20 1
# limpou preds
# 173
# 39 1
# limpou preds
# 174
# 33 1
# limpou preds
# 175
# 73 1
# limpou preds
# 176
# 68 1
# limpou preds
# 177
# 24 1
# limpou preds
# 178
# 20 1
# limpou preds
# 179
# 60 1
# limpou preds
# 180
# 19 1
# limpou preds
# 181
# 15 1
# limpou preds
# 182
# 24 1
# limpou preds
# 183
# 18 1
# limpou preds
# 184
# 42 1
# limpou preds
# 185
# 30 1
# limpou preds
# 186
# 28 1
# limpou preds
# 187
# 38 1
# limpou preds
# 188
# 5 1
# limpou preds
# 189
# 29 1
# limpou preds
# 190
# 23 1
# limpou preds
# 191
# 28 1
# limpou preds
# 192
# 40 1
# limpou preds
# 193
# 43 1
# limpou preds
# 194
# 48 1
# limpou preds
# 195
# 41 1
# limpou preds
# 196
# 18 1
# limpou preds
# 197
# 37 1
# limpou preds
# 198
# 47 1
# limpou preds
# 199
# 23 1
# limpou preds
# 200
# 37 1
# limpou preds
# 201
# 42 1
# limpou preds
# 202
# 35 1
# limpou preds
# 203
# 8 1
# limpou preds
# 204
# 46 1
# limpou preds
# 205
# 19 1
# limpou preds
# 206
# 18 1
# limpou preds
# 207
# 32 1
# limpou preds
# 208
# 63 1
# limpou preds
# 209
# 32 1
# limpou preds
# 210
# 20 1
# limpou preds
# 211
# 27 1
# limpou preds
# 212
# 28 1
# limpou preds
# 213
# 54 1
# limpou preds
# 214
# 62 1
# limpou preds
# 215
# 11 1
# limpou preds
# 216
# 24 1
# limpou preds
# 217
# 38 1
# limpou preds
# 218
# 10 1
# limpou preds
# 219
# 19 1
# limpou preds
# 220
# 40 1
# limpou preds
# 221
# 10 1
# limpou preds
# 222
# 27 1
# limpou preds
# 223
# 25 1
# limpou preds
# 224
# 26 1
# limpou preds
# 225
# 19 1
# limpou preds
# 226
# 23 1
# limpou preds
# 227
# 79 1
# limpou preds
# 228
# 85 1
# limpou preds
# 229
# 41 1
# limpou preds
# 230
# 21 1
# limpou preds
# 231
# 42 1
# limpou preds
# 232
# 30 1
# limpou preds
# 233
# 23 1
# limpou preds
# 234
# 37 1
# limpou preds
# 235
# 31 1
# limpou preds
# 236
# 58 1
# limpou preds
# 237
# 21 1
# limpou preds
# 238
# 18 1
# limpou preds
# 239
# 38 1
# limpou preds
# 240
# 36 1
# limpou preds
# 241
# 17 1
# limpou preds
# 242
# 28 1
# limpou preds
# 243
# 5 1
# limpou preds
# 244
# 23 1
# limpou preds
# 245
# 14 1
# limpou preds
# 246
# 17 1
# limpou preds
# 247
# 40 1
# limpou preds
# 248
# 93 1
# limpou preds
# 249
# 39 1
# limpou preds
# 250
# 23 1
# limpou preds
# 251
# 46 1
# limpou preds
# 252
# 50 1
# limpou preds
# 253
# 30 1
# limpou preds
# 254
# 18 1
# limpou preds
# 255
# 20 1
# limpou preds
# 256
# 49 1
# limpou preds
# 257
# 40 1
# limpou preds
# 258
# 54 1
# limpou preds
# 259
# 41 1
# limpou preds
# 260
# 16 1
# limpou preds
# 261
# 16 1
# limpou preds
# 262
# 20 1
# limpou preds
# 263
# 44 1
# limpou preds
# 264
# 23 1
# limpou preds
# 265
# 42 1
# limpou preds
# 266
# 40 1
# limpou preds
# 267
# 25 1
# limpou preds
# 268
# 56 1
# limpou preds
# 269
# 48 1
# limpou preds
# 270
# 4 1
# limpou preds
# 271
# 37 1
# limpou preds
# 272
# 21 1
# limpou preds
# 273
# 27 1
# limpou preds
# 274
# 25 1
# limpou preds
# 275
# 24 1
# limpou preds
# 276
# 34 1
# limpou preds
# 277
# 42 1
# limpou preds
# 278
# 40 1
# limpou preds
# 279
# 21 1
# limpou preds
# 280
# 61 1
# limpou preds
# 281
# 29 1
# limpou preds
# 282
# 19 1
# limpou preds
# 283
# 18 1
# limpou preds
# 284
# 82 1
# limpou preds
# 285
# 29 1
# limpou preds
# 286
# 17 1
# limpou preds
# 287
# 29 1
# limpou preds
# 288
# 58 1
# limpou preds
# 289
# 37 1
# limpou preds
# 290
# 38 1
# limpou preds
# 291
# 36 1
# limpou preds
# 292
# 9 1
# limpou preds
# 293
# 22 1
# limpou preds
# 294
# 42 1
# limpou preds
# 295
# 40 1
# limpou preds
# 296
# 31 1
# limpou preds
# 297
# 33 1
# limpou preds
# 298
# 33 1
# limpou preds
# 299
# 21 1
# limpou preds
# 300
# 34 1
# limpou preds
# 301
# 24 1
# limpou preds
# 302
# 28 1
# limpou preds
# 303
# 15 1
# limpou preds
# 304
# 27 1
# limpou preds
# 305
# 29 1
# limpou preds
# 306
# 40 1
# limpou preds
# 307
# 15 1
# limpou preds
# 308
# 49 1
# limpou preds
# 309
# 16 1
# limpou preds
# 310
# 45 1
# limpou preds
# 311
# 27 1
# limpou preds
# 312
# 9 1
# limpou preds
# 313
# 28 1
# limpou preds
# 314
# 27 1
# limpou preds
# 315
# 33 1
# limpou preds
# 316
# 71 1
# limpou preds
# 317
# 104 1
# limpou preds
# 318
# 36 1
# limpou preds
# 319
# 37 1
# limpou preds
# 320
# 24 1
# limpou preds
# 321
# 52 1
# limpou preds
# 322
# 25 1
# limpou preds
# 323
# 17 1
# limpou preds
# 324
# 20 1
# limpou preds
# 325
# 16 1
# limpou preds
# 326
# 19 1
# limpou preds
# 327
# 23 1
# limpou preds
# 328
# 45 1
# limpou preds
# 329
# 25 1
# limpou preds
# 330
# 23 1
# limpou preds
# 331
# 47 1
# limpou preds
# 332
# 133 1
# limpou preds
# 333
# 20 1
# limpou preds
# 334
# 43 1
# limpou preds
# 335
# 9 1
# limpou preds
# 336
# 19 1
# limpou preds
# 337
# 30 1
# limpou preds
# 338
# 30 1
# limpou preds
# 339
# 57 1
# limpou preds
# 340
# 48 1
# limpou preds
# 341
# 27 1
# limpou preds
# 342
# 36 1
# limpou preds
# 343
# 33 1
# limpou preds
# 344
# 18 1
# limpou preds
# 345
# 22 1
# limpou preds
# 346
# 29 1
# limpou preds
# 347
# 14 1
# limpou preds
# 348
# 25 1
# limpou preds
# 349
# 21 1
# limpou preds
# 350
# 10 1
# limpou preds
# 351
# 40 1
# limpou preds
# 352
# 29 1
# limpou preds
# 353
# 35 1
# limpou preds
# 354
# 24 1
# limpou preds
# 355
# 32 1
# limpou preds
# 356
# 26 1
# limpou preds
# 357
# 26 1
# limpou preds
# 358
# 54 1
# limpou preds
# 359
# 23 1
# limpou preds
# 360
# 72 1
# limpou preds
# 361
# 35 1
# limpou preds
# 362
# 17 1
# limpou preds
# 363
# 34 1
# limpou preds
# 364
# 21 1
# limpou preds
# 365
# 44 1
# limpou preds
# 366
# 25 1
# limpou preds
# 367
# 3 1
# limpou preds
# 368
# 31 1
# limpou preds
# 369
# 37 1
# limpou preds
# 370
# 9 1
# limpou preds
# 371
# 14 1
# limpou preds
# 372
# 20 1
# limpou preds
# 373
# 35 1
# limpou preds
# 374
# 21 1
# limpou preds
# 375
# 20 1
# limpou preds
# 376
# 43 1
# limpou preds
# 377
# 59 1
# limpou preds
# 378
# 31 1
# limpou preds
# 379
# 29 1
# limpou preds
# 380
# 20 1
# limpou preds
# 381
# 20 1
# limpou preds
# 382
# 25 1
# limpou preds
# 383
# 35 1
# limpou preds
# 384
# 37 1
# limpou preds
# 385
# 17 1
# limpou preds
# 386
# 41 1
# limpou preds
# 387
# 16 1
# limpou preds
# 388
# 56 1
# limpou preds
# 389
# 9 1
# limpou preds
# 390
# 25 1
# limpou preds
# 391
# 34 1
# limpou preds
# 392
# 65 1
# limpou preds
# 393
# 19 1
# limpou preds
# 394
# 45 1
# limpou preds
# 395
# 14 1
# limpou preds
# 396
# 14 1
# limpou preds
# 397
# 23 1
# limpou preds
# 398
# 16 1
# limpou preds
# 399
# 40 1
# limpou preds
# 400
# 28 1
# limpou preds
# 401
# 34 1
# limpou preds
# 402
# 14 1
# limpou preds
# 403
# 85 1
# limpou preds
# 404
# 65 1
# limpou preds
# 405
# 30 1
# limpou preds
# 406
# 20 1
# limpou preds
# 407
# 3 1
# limpou preds
# 408
# 18 1
# limpou preds
# 409
# 36 1
# limpou preds
# 410
# 82 1
# limpou preds
# 411
# 48 1
# limpou preds
# 412
# 13 1
# limpou preds
# 413
# 30 1
# limpou preds
# 414
# 57 1
# limpou preds
# 415
# 89 1
# limpou preds
# 416
# 21 1
# limpou preds
# 417
# 29 1
# limpou preds
# 418
# 87 1
# limpou preds
# 419
# 38 1
# limpou preds
# 420
# 24 1
# limpou preds
# 421
# 44 1
# limpou preds
# 422
# 11 1
# limpou preds
# 423
# 69 1
# limpou preds
# 424
# 25 1
# limpou preds
# 425
# 16 1
# limpou preds
# 426
# 32 1
# limpou preds
# 427
# 30 1
# limpou preds
# 428
# 40 1
# limpou preds
# 429
# 18 1
# limpou preds
# 430
# 18 1
# limpou preds
# 431
# 15 1
# limpou preds
# 432
# 38 1
# limpou preds
# 433
# 62 1
# limpou preds
# 434
# 26 1
# limpou preds
# 435
# 11 1
# limpou preds
# 436
# 13 1
# limpou preds
# 437
# 6 1
# limpou preds
# 438
# 39 1
# limpou preds
# 439
# 35 1
# limpou preds
# 440
# 30 1
# limpou preds
# 441
# 26 1
# limpou preds
# 442
# 49 1
# limpou preds
# 443
# 16 1
# limpou preds
# 444
# 25 1
# limpou preds
# 445
# 17 1
# limpou preds
# 446
# 49 1
# limpou preds
# 447
# 14 1
# limpou preds
# 448
# 53 1
# limpou preds
# 449
# 37 1
# limpou preds
# 450
# 38 1
# limpou preds
# 451
# 28 1
# limpou preds
# 452
# 27 1
# limpou preds
# 453
# 165 1
# limpou preds
# 454
# 32 1
# limpou preds
# 455
# 57 1
# limpou preds
# 456
# 44 1
# limpou preds
# 457
# 30 1
# limpou preds
# 458
# 11 1
# limpou preds
# 459
# 45 1
# limpou preds
# 460
# 53 1
# limpou preds
# 461
# 31 1
# limpou preds
# 462
# 24 1
# limpou preds
# 463
# 15 1
# limpou preds
# 464
# 58 1
# limpou preds
# 465
# 22 1
# limpou preds
# 466
# 13 1
# limpou preds
# 467
# 35 1
# limpou preds
# 468
# 22 1
# limpou preds
# 469
# 23 1
# limpou preds
# 470
# 171 1
# limpou preds
# 471
# 10 1
# limpou preds
# 472
# 19 1
# limpou preds
# 473
# 8 1
# limpou preds
# 474
# 21 1
# limpou preds
# 475
# 78 1
# limpou preds
# 476
# 5 1
# limpou preds
# 477
# 10 1
# limpou preds
# 478
# 22 1
# limpou preds
# 479
# 28 1
# limpou preds
# 480
# 14 1
# limpou preds
# 481
# 25 1
# limpou preds
# 482
# 20 1
# limpou preds
# 483
# 47 1
# limpou preds
# 484
# 22 1
# limpou preds
# 485
# 52 1
# limpou preds
# 486
# 43 1
# limpou preds
# 487
# 55 1
# limpou preds
# 488
# 32 1
# limpou preds
# 489
# 21 1
# limpou preds
# 490
# 21 1
# limpou preds
# 491
# 11 1
# limpou preds
# 492
# 45 1
# limpou preds
# 493
# 13 1
# limpou preds
# 494
# 63 1
# limpou preds
# 495
# 28 1
# limpou preds
# 496
# 43 1
# limpou preds
# 497
# 25 1
# limpou preds
# 498
# 34 1
# limpou preds
# 499
# [[['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-evento', 'I-evento', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'B-estrutura', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-estrutura', 'I-estrutura', 'I-estrutura', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['Ocorreu', '3.6 bilhões de anos atrás', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O']], [['O', 'B-eoceno', 'I-eoceno', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'B-animais', 'I-animais', 'O', 'O', 'O', 'B-anelídeos', 'O', 'B-artrópodes', 'O', 'B-equinódermes', 'O', 'B-braquiópodes', 'O', 'B-onicóforos', 'O', 'B-esponjas', 'O', 'B-moluscos', 'I-moluscos', 'O', 'B-monoplacófiros', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-sódio', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-jazidas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-jazidas', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'B-cráton', 'O', 'O', 'O', 'O', 'O', 'O', '(', 'O', ')', 'O', 'O', 'O', 'O', 'B-formação', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-formação', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'O', 'O', 'B-evento', 'O', 'O', 'O', 'O', 'O', 'O', 'I-evento', 'O', 'O', 'O', 'O', '.']], [['O', 'B-autor', 'O', 'O', 'I-autor', 'O', 'O', 'I-autor', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-autor', 'O', 'O', 'O', 'O', '.', 'O', 'O']], [['O', 'B-conglomerado', 'O', 'O', 'I-conglomerado', 'O', 'O', 'O', 'O', 'O', 'O', 'O', '.', 'O']], [['O', 'B-DATA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']], [['O', 'O', 'B-EVENT', 'B-EVENT', 'O', 'O', 'B-EVENT', 'O', 'O', 'O', ...
# ok
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# 28 1
# limpou preds
# 0
# 51 1
# limpou preds
# 1
# 42 1
# limpou preds
# 2
# 29 1
# limpou preds
# 3
# 58 1
# limpou preds
# 4
# 47 1
# limpou preds
# 5
# 41 1
# limpou preds
# 6
# 5 1
# limpou preds
# 7
# 20 1
# limpou preds
# 8
# 47 1
# limpou preds
# 9
# 24 1
# limpou preds
# 10
# 23 1
# limpou preds
# 11
# 12 1
# limpou preds
# 12
# 45 1
# limpou preds
# 13
# 23 1
# limpou preds
# 14
# 28 1
# limpou preds
# 15
# 50 1
# limpou preds
# 16
# 17 1
# limpou preds
# 17
# 23 1
# limpou preds
# 18
# 14 1
# limpou preds
# 19
# 66 1
# limpou preds
# 20
# 33 1
# limpou preds
# 21
# 24 1
# limpou preds
# 22
# 22 1
# limpou preds
# 23
# 44 1
# limpou preds
# 24
# 24 1
# limpou preds
# 25
# 16 1
# limpou preds
# 26
# 24 1
# limpou preds
# 27
# 46 1
# limpou preds
# 28
# 47 1
# limpou preds
# 29
# 41 1
# limpou preds
# 30
# 38 1
# limpou preds
# 31
# 36 1
# limpou preds
# 32
# 32 1
# limpou preds
# 33
# 75 1
# limpou preds
# 34
# 26 1
# limpou preds
# 35
# 53 1
# limpou preds
# 36
# 19 1
# limpou preds
# 37
# 42 1
# limpou preds
# 38
# 33 1
# limpou preds
# 39
# 49 1
# limpou preds
# 40
# 35 1
# limpou preds
# 41
# 53 1
# limpou preds
# 42
# 22 1
# limpou preds
# 43
# 27 1
# limpou preds
# 44
# 44 1
# limpou preds
# 45
# 37 1
# limpou preds
# 46
# 43 1
# limpou preds
# 47
# 25 1
# limpou preds
# 48
# 3 1
# limpou preds
# 49
# 19 1
# limpou preds
# 50
# 20 1
# limpou preds
# 51
# 22 1
# limpou preds
# 52
# 40 1
# limpou preds
# 53
# 27 1
# limpou preds
# 54
# 25 1
# limpou preds
# 55
# 21 1
# limpou preds
# 56
# 9 1
# limpou preds
# 57
# 26 1
# limpou preds
# 58
# 43 1
# limpou preds
# 59
# 43 1
# limpou preds
# 60
# 63 1
# limpou preds
# 61
# 10 1
# limpou preds
# 62
# 40 1
# limpou preds
# 63
# 25 1
# limpou preds
# 64
# 9 1
# limpou preds
# 65
# 45 1
# limpou preds
# 66
# 66 1
# limpou preds
# 67
# 36 1
# limpou preds
# 68
# 18 1
# limpou preds
# 69
# 36 1
# limpou preds
# 70
# 45 1
# limpou preds
# 71
# 44 1
# limpou preds
# 72
# 32 1
# limpou preds
# 73
# 36 1
# limpou preds
# 74
# 34 1
# limpou preds
# 75
# 30 1
# limpou preds
# 76
# 19 1
# limpou preds
# 77
# 31 1
# limpou preds
# 78
# 68 1
# limpou preds
# 79
# 41 1
# limpou preds
# 80
# 30 1
# limpou preds
# 81
# 32 1
# limpou preds
# 82
# 43 1
# limpou preds
# 83
# 14 1
# limpou preds
# 84
# 23 1
# limpou preds
# 85
# 10 1
# limpou preds
# 86
# 18 1
# limpou preds
# 87
# 258 1
# limpou preds
# 88
# 24 1
# limpou preds
# 89
# 23 1
# limpou preds
# 90
# 29 1
# limpou preds
# 91
# 14 1
# limpou preds
# 92
# 44 1
# limpou preds
# 93
# 60 1
# limpou preds
# 94
# 41 1
# limpou preds
# 95
# 74 1
# limpou preds
# 96
# 24 1
# limpou preds
# 97
# 44 1
# limpou preds
# 98
# 20 1
# limpou preds
# 99
# 61 1
# limpou preds
# 100
# 28 1
# limpou preds
# 101
# 42 1
# limpou preds
# 102
# 42 1
# limpou preds
# 103
# 30 1
# limpou preds
# 104
# 40 1
# limpou preds
# 105
# 15 1
# limpou preds
# 106
# 24 1
# limpou preds
# 107
# 29 1
# limpou preds
# 108
# 21 1
# limpou preds
# 109
# 58 1
# limpou preds
# 110
# 45 1
# limpou preds
# 111
# 20 1
# limpou preds
# 112
# 39 1
# limpou preds
# 113
# 91 1
# limpou preds
# 114
# 25 1
# limpou preds
# 115
# 19 1
# limpou preds
# 116
# 51 1
# limpou preds
# 117
# 44 1
# limpou preds
# 118
# 38 1
# limpou preds
# 119
# 65 1
# limpou preds
# 120
# 40 1
# limpou preds
# 121
# 33 1
# limpou preds
# 122
# 23 1
# limpou preds
# 123
# 45 1
# limpou preds
# 124
# 59 1
# limpou preds
# 125
# 83 1
# limpou preds
# 126
# 17 1
# limpou preds
# 127
# 17 1
# limpou preds
# 128
# 25 1
# limpou preds
# 129
# 27 1
# limpou preds
# 130
# 46 1
# limpou preds
# 131
# 63 1
# limpou preds
# 132
# 33 1
# limpou preds
# 133
# 28 1
# limpou preds
# 134
# 35 1
# limpou preds
# 135
# 49 1
# limpou preds
# 136
# 33 1
# limpou preds
# 137
# 44 1
# limpou preds
# 138
# 20 1
# limpou preds
# 139
# 43 1
# limpou preds
# 140
# 29 1
# limpou preds
# 141
# 26 1
# limpou preds
# 142
# 46 1
# limpou preds
# 143
# 21 1
# limpou preds
# 144
# 3 1
# limpou preds
# 145
# 60 1
# limpou preds
# 146
# 23 1
# limpou preds
# 147
# 49 1
# limpou preds
# 148
# 35 1
# limpou preds
# 149
# 5 1
# limpou preds
# 150
# 58 1
# limpou preds
# 151
# 43 1
# limpou preds
# 152
# 55 1
# limpou preds
# 153
# 77 1
# limpou preds
# 154
# 32 1
# limpou preds
# 155
# 19 1
# limpou preds
# 156
# 36 1
# limpou preds
# 157
# 26 1
# limpou preds
# 158
# 16 1
# limpou preds
# 159
# 32 1
# limpou preds
# 160
# 30 1
# limpou preds
# 161
# 106 1
# limpou preds
# 162
# 35 1
# limpou preds
# 163
# 44 1
# limpou preds
# 164
# 27 1
# limpou preds
# 165
# 39 1
# limpou preds
# 166
# 19 1
# limpou preds
# 167
# 28 1
# limpou preds
# 168
# 23 1
# limpou preds
# 169
# 15 1
# limpou preds
# 170
# 51 1
# limpou preds
# 171
# 31 1
# limpou preds
# 172
# 23 1
# limpou preds
# 173
# 33 1
# ...
# ok
# [['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O'], ['O']]
# 28 1
# limpou preds
# 0
# 43 1
# limpou preds
# 1
# 18 1
# limpou preds
# 2
# 22 1
# limpou preds
# 3
# 23 1
# limpou preds
# 4
# 80 1
# limpou preds
# 5
# 83 1
# limpou preds
# 6
# 36 1
# limpou preds
# 7
# 57 1
# limpou preds
# 8
# 52 1
# limpou preds
# 9
# 18 1
# limpou preds
# 10
# 101 1
# limpou preds
# 11
# 33 1
# limpou preds
# 12
# 17 1
# limpou preds
# 13
# 26 1
# limpou preds
# 14
# 36 1
# limpou preds
# 15
# 32 1
# limpou preds
# 16
# 18 1
# limpou preds
# 17
# 26 1
# limpou preds
# 18
# 49 1
# limpou preds
# 19
# 44 1
# limpou preds
# 20
# 27 1
# limpou preds
# 21
# 20 1
# limpou preds
# 22
# 124 1
# limpou preds
# 23
# 41 1
# limpou preds
# 24
# 53 1
# limpou preds
# 25
# 50 1
# limpou preds
# 26
# 29 1
# limpou preds
# 27
# 47 1
# limpou preds
# 28
# 49 1
# limpou preds
# 29
# 238 1
# limpou preds
# 30
# 31 1
# limpou preds
# 31
# 30 1
# limpou preds
# 32
# 40 1
# limpou preds
# 33
# 35 1
# limpou preds
# 34
# 33 1
# limpou preds
# 35
# 130 1
# limpou preds
# 36
# 93 1
# limpou preds
# 37
# 33 1
# limpou preds
# 38
# 28 1
# limpou preds
# 39
# 46 1
# limpou preds
# 40
# 28 1
# limpou preds
# 41
# 18 1
# limpou preds
# 42
# 9 1
# limpou preds
# 43
# 24 1
# limpou preds
# 44
# 36 1
# limpou preds
# 45
# 25 1
# limpou preds
# 46
# 24 1
# limpou preds
# 47
# 102 1
# limpou preds
# 48
# 42 1
# limpou preds
# 49
# 52 1
# limpou preds
# 50
# 44 1
# limpou preds
# 51
# 67 1
# limpou preds
# 52
# 64 1
# limpou preds
# 53
# 37 1
# limpou preds
# 54
# 39 1
# limpou preds
# 55
# 69 1
# limpou preds
# 56
# 48 1
# limpou preds
# 57
# 44 1
# limpou preds
# 58
# 52 1
# limpou preds
# 59
# 73 1
# limpou preds
# 60
# 63 1
# limpou preds
# 61
# 63 1
# limpou preds
# 62
# 102 1
# limpou preds
# 63
# 28 1
# limpou preds
# 64
# 63 1
# limpou preds
# 65
# 56 1
# limpou preds
# 66
# 22 1
# limpou preds
# 67
# 35 1
# limpou preds
# 68
# 52 1
# limpou preds
# 69
# 55 1
# limpou preds
# 70
# 74 1
# limpou preds
# 71
# 46 1
# limpou preds
# 72
# 57 1
# limpou preds
# 73
# 48 1
# limpou preds
# 74
# 54 1
# limpou preds
# 75
# 25 1
# limpou preds
# 76
# 19 1
# limpou preds
# 77
# 35 1
# limpou preds
# 78
# 54 1
# limpou preds
# 79
# 44 1
# limpou preds
# 80
# 49 1
# limpou preds
# 81
# 29 1
# limpou preds
# 82
# 51 1
# limpou preds
# 83
# 72 1
# limpou preds
# 84
# 79 1
# limpou preds
# 85
# 19 1
# limpou preds
# 86
# 20 1
# limpou preds
# 87
# 70 1
# limpou preds
# 88
# 58 1
# limpou preds
# 89
# 32 1
# limpou preds
# 90
# 36 1
# limpou preds
# 91
# 65 1
# limpou preds
# 92
# 82 1
# limpou preds
# 93
# 57 1
# limpou preds
# 94
# 38 1
# limpou preds
# 95
# 33 1
# limpou preds
# 96
# 42 1
# limpou preds
# 97
# 20 1
# limpou preds
# 98
# 166 1
# limpou preds
# 99
# 28 1
# limpou preds
# 100
# 28 1
# limpou preds
# 101
# 43 1
# limpou preds
# 102
# 75 1
# limpou preds
# 103
# 25 1
# limpou preds
# 104
# 33 1
# limpou preds
# 105
# 27 1
# limpou preds
# 106
# 45 1
# limpou preds
# 107
# 92 1
# limpou preds
# 108
# 20 1
# limpou preds
# 109
# 44 1
# limpou preds
# 110
# 21 1
# limpou preds
# 111
# 29 1
# limpou preds
# 112
# 45 1
# limpou preds
# 113
# 15 1
# limpou preds
# 114
# 30 1
# limpou preds
# 115
# 38 1
# limpou preds
# 116
# 43 1
# limpou preds
# 117
# 40 1
# limpou preds
# 118
# 32 1
# limpou preds
# 119
# 155 1
# limpou preds
# 120
# 54 1
# limpou preds
# 121
# 29 1
# limpou preds
# 122
# 53 1
# limpou preds
# 123
# 55 1
# limpou preds
# 124
# 94 1
# limpou preds
# 125
# 20 1
# limpou preds
# 126
# 40 1
# limpou preds
# 127
# 18 1
# limpou preds
# 128
# 18 1
# limpou preds
# 129
# 40 1
# limpou preds
# 130
# 43 1
# limpou preds
# 131
# 86 1
# limpou preds
# 132
# 24 1
# limpou preds
# 133
# 21 1
# limpou preds
# 134
# 27 1
# limpou preds
# 135
# 51 1
# limpou preds
# 136
# 44 1
# limpou preds
# 137
# 12 1
# limpou preds
# 138
# 16 1
# limpou preds
# 139
# 81 1
# limpou preds
# 140
# 13 1
# limpou preds
# 141
# 8 1
# limpou preds
# 142
# 13 1
# limpou preds
# 143
# 61 1
# limpou preds
# 144
# 50 1
# limpou preds
# 145
# 25 1
# limpou preds
# 146
# 28 1
# limpou preds
# 147
# 37 1
# limpou preds
# 148
# 18 1
# limpou preds
# 149
# 20 1
# limpou preds
# 150
# 37 1
# limpou preds
# 151
# 37 1
# limpou preds
# 152
# 21 1
# limpou preds
# 153
# 22 1
# limpou preds
# 154
# 28 1
# limpou preds
# 155
# 18 1
# limpou preds
# 156
# 36 1
# limpou preds
# 157
# 40 1
# limpou preds
# 158
# 30 1
# limpou preds
# 159
# 43 1
# limpou preds
# 160
# 49 1
# limpou preds
# 161
# 57 1
# limpou preds
# 162
# 57 1
# limpou preds
# 163
# 32 1
# limpou preds
# 164
# 28 1
# limpou preds
# 165
# 106 1
# limpou preds
# 166
# 31 1
# limpou preds
# 167
# 19 1
# limpou preds
# 168
# 51 1
# limpou preds
# 169
# 28 1
# limpou preds
# 170
# 41 1
# limpou preds
# 171
# 17 1
# limpou preds
# 172
# 22 1
# limpou preds
# 173
# 4 1
# limpou preds
# 174
# 7 1
# limpou preds
# 175
# 15 1
# limpou preds
# 176
# 27 1
# limpou preds
# 177
# 18 1
# limpou preds
# 178
# 46 1
# limpou preds
# 179
# 48 1
# limpou preds
# 180
# 46 1
# limpou preds
# 181
# 39 1
# limpou preds
# 182
# 44 1
# limpou preds
# 183
# 60 1
# limpou preds
# 184
# 40 1
# limpou preds
# 185
# 75 1
# limpou preds
# 186
# 30 1
# limpou preds
# 187
# 28 1
# limpou preds
# 188
# 30 1
# limpou preds
# 189
# 15 1
# limpou preds
# 190
# 32 1
# limpou preds
# 191
# 79 1
# limpou preds
# 192
# 42 1
# limpou preds
# 193
# 91 1
# limpou preds
# 194
# 64 1
# limpou preds
# 195
# 42 1
# limpou preds
# 196
# 30 1
# limpou preds
# 197
# 55 1
# limpou preds
# 198
# 47 1
# limpou preds
# 199
# 52 1
# limpou preds
# 200
# 20 1
# limpou preds
# 201
# 40 1
# limpou preds
# 202
# 26 1
# limpou preds
# 203
# 38 1
# limpou preds
# 204
# 41 1
# limpou preds
# 205
# 78 1
# limpou preds
# 206
# 56 1
# limpou preds
# 207
# 74 1
# limpou preds
# 208
# 258 1
# limpou preds
# 209
# 248 1
# limpou preds
# 210
# 59 1
# limpou preds
# 211
# 14 1
# limpou preds
# 212
# 20 1
# limpou preds
# 213
# 102 1
# limpou preds
# 214
# 38 1
# limpou preds
# 215
# 17 1
# limpou preds
# 216
# 26 1
# limpou preds
# 217
# 23 1
# limpou preds
# 218
# 61 1
# limpou preds
# 219
# 22 1
# limpou preds
# 220
# 46 1
# limpou preds
# 221
# 21 1
# limpou preds
# 222
# 7 1
# limpou preds
# 223
# 29 1
# limpou preds
# 224
# 119 1
# limpou preds
# 225
# 28 1
# limpou preds
# 226
# 55 1
# limpou preds
# 227
# 19 1
# limpou preds
# 228
# 51 1
# limpou preds
# 229
# 17 1
# limpou preds
# 230
# 44 1
# limpou preds
# 231
# 53 1
# limpou preds
# 232
# 38 1
# limpou preds
# 233
# 45 1
# limpou preds
# 234
# 19 1
# limpou preds
# 235
# 44 1
# limpou preds
# 236
# 11 1
# limpou preds
# 237
# 78 1
# limpou preds
# 238
# 34 1
# limpou preds
# 239
# 14 1
# limpou preds
# 240
# 33 1
# limpou preds
# 241
# 17 1
# limpou preds
# 242
# 20 1
# limpou preds
# 243
# 101 1
# limpou preds
# 244
# 38 1
# limpou preds
# 245
# 39 1
# limpou preds
# 246
# 43 1
# limpou preds
# 247
# 12 1
# limpou preds
# 248
# 15 1
# limpou preds
# 249
# 17 1
# limpou preds
# 250
# 46 1
# limpou preds
# 251
# 48 1
# limpou preds
# 252
# 41 1
# limpou preds
# 253
# 35 1
# limpou preds
# 254
# 28 1
# limpou preds
# 255
# 31 1
# limpou preds
# 256
# 38 1
# limpou preds
# 257
# 55 1
# limpou preds
# 258
# 16 1
# limpou preds
# 259
# 50 1
# limpou preds
# 260
# 39 1
# limpou preds
# 261
# 26 1
# limpou preds
# 262
# 32 1
# limpou preds
# 263
# 24 1
# limpou preds
# 264
# 20 1
# limpou preds
# 265
# 25 1
# limpou preds
# 266
# 42 1
# limpou preds
# 267
# 27 1
# limpou preds
# 268
# 17 1
# limpou preds
# 269
# 29 1
# limpou preds
# 270
# 22 1
# limpou preds
# 271
# 26 1
# limpou preds
# 272
# 21 1
# limpou preds
# 273
# 37 1
# limpou preds
# 274
# 39 1
# limpou preds
# 275
# 25 1
# limpou preds
# 276
# 50 1
# limpou preds
# 277
# 41 1
# limpou preds
# 278
# 78 1
# limpou preds
# 279
# 47 1
# limpou preds
# 280
# 52 1
# limpou preds
# 281
# 26 1
# limpou preds
# 282
# 42 1
# limpou preds
# 283
# 101 1
# limpou preds
# 284
# 53 1
# limpou preds
# 285
# 102 1
# limpou preds
# 286
# 78 1
# limpou preds
# 287
# 33 1
# limpou preds
# 288
# 25 1
# limpou preds
# 289
# 57 1
# limpou preds
# 290
# 15 1
# limpou preds
# 291
# 54 1
# limpou preds
# 292
# 40 1
# limpou preds
# 293
# 48 1
# limpou preds
# 294
# 64 1
# limpou preds
# 295
# 37 1
# limpou preds
# 296
# 47 1
# limpou preds
# 297
# 45 1
# limpou preds
# 298
# 50 1
# limpou preds
# 299
# 26 1
# limpou preds
# 300
# 23 1
# limpou preds
# 301
# 146 1
# limpou preds
# 302
# 83 1
# limpou preds
# 303
# 81 1
# limpou preds
# 304
# 15 1
# limpou preds
# 305
# 30 1
# limpou preds
# 306
# 47 1
# limpou preds
# 307
# 6 1
# limpou preds
# 308
# 57 1
# limpou preds
# 309
# 31 1
# limpou preds
# 310
# 53 1
# limpou preds
# 311
# 161 1
# limpou preds
# 312
# 27 1
# limpou preds
# 313
# 16 1
# limpou preds
# 314
# 46 1
# limpou preds
# 315
# 33 1
# limpou preds
# 316
# 32 1
# limpou preds
# 317
# 34 1
# limpou preds
# 318
# 29 1
# limpou preds
# 319
# 21 1
# limpou preds
# 320
# 52 1
# limpou preds
# 321
# 44 1
# limpou preds
# 322
# 60 1
# limpou preds
# 323
# 46 1
# limpou preds
# 324
# 15 1
# limpou preds
# 325
# 23 1
# limpou preds
# 326
# 38 1
# limpou preds
# 327
# 23 1
# limpou preds
# 328
# 21 1
# limpou preds
# 329
# 41 1
# limpou preds
# 330
# 31 1
# limpou preds
# 331
# 51 1
# limpou preds
# 332
# 53 1
# limpou preds
# 333
# 13 1
# limpou preds
# 334
# 50 1
# limpou preds
# 335
# 44 1
# limpou preds
# 336
# 39 1
# limpou preds
# 337
# 64 1
# limpou preds
# 338
# 9 1
# limpou preds
# 339
# 13 1
# limpou preds
# 340
# 36 1
# limpou preds
# 341
# 27 1
# limpou preds
# 342
# 64 1
# limpou preds
# 343
# 23 1
# limpou preds
# 344
# 30 1
# limpou preds
# 345
# 65 1
# limpou preds
# 346
# 23 1
# limpou preds
# 347
# 40 1
# limpou preds
# 348
# 30 1
# limpou preds
# 349
# 11 1
# limpou preds
# 350
# 50 1
# limpou preds
# 351
# 30 1
# limpou preds
# 352
# 32 1
# limpou preds
# 353
# 19 1
# limpou preds
# 354
# 16 1
# limpou preds
# 355
# 23 1
# limpou preds
# 356
# 42 1
# limpou preds
# 357
# 61 1
# limpou preds
# 358
# 7 1
# limpou preds
# 359
# 41 1
# limpou preds
# 360
# 48 1
# limpou preds
# 361
# 46 1
# limpou preds
# 362
# 59 1
# limpou preds
# 363
# 27 1
# limpou preds
# 364
# 34 1
# limpou preds
# 365
# 23 1
# limpou preds
# 366
# 23 1
# limpou preds
# 367
# 41 1
# limpou preds
# 368
# 13 1
# limpou preds
# 369
# 39 1
# limpou preds
# 370
# 24 1
# limpou preds
# 371
# 63 1
# limpou preds
# 372
# 15 1
# limpou preds
# 373
# 18 1
# limpou preds
# 374
# 41 1
# limpou preds
# 375
# 33 1
# limpou preds
# 376
# 36 1
# limpou preds
# 377
# 50 1
# limpou preds
# 378
# 21 1
# limpou preds
# 379
# 3 1
# limpou preds
# 380
# 11 1
# limpou preds
# 381
# 32 1
# limpou preds
# 382
# 58 1
# limpou preds
# 383
# 34 1
# limpou preds
# 384
# 39 1
# limpou preds
# 385
# 33 1
# limpou preds
# 386
# 27 1
# limpou preds
# 387
# 79 1
# limpou preds
# 388
# 18 1
# limpou preds
# 389
# 44 1
# limpou preds
# 390
# 38 1
# limpou preds
# 391
# 32 1
# limpou preds
# 392
# 45 1
# limpou preds
# 393
# 33 1
# limpou preds
# 394
# 19 1
# limpou preds
# 395
# 57 1
# limpou preds
# 396
# 23 1
# limpou preds
# 397
# 53 1
# limpou preds
# 398
# 29 1
# limpou preds
# 399
# 46 1
# limpou preds
# 400
# 30 1
# limpou preds
# 401
# 17 1
# limpou preds
# 402
# 30 1
# limpou preds
# 403
# 79 1
# limpou preds
# 404
# 21 1
# limpou preds
# 405
# 22 1
# limpou preds
# 406
# 21 1
# limpou preds
# 407
# 26 1
# limpou preds
# 408
# 16 1
# limpou preds
# 409
# 30 1
# limpou preds
# 410
# 36 1
# limpou preds
# 411
# 25 1
# limpou preds
# 412
# 18 1
# limpou preds
# 413
# 42 1
# limpou preds
# 414
# 38 1
# limpou preds
# 415
# 15 1
# limpou preds
# 416
# 51 1
# limpou preds
# 417
# 21 1
# limpou preds
# 418
# 15 1
# limpou preds
# 419
# 21 1
# limpou preds
# 420
# 59 1
# limpou preds
# 421
# 41 1
# limpou preds
# 422
# 21 1
# limpou preds
# 423
# 23 1
# limpou preds
# 424
# 30 1
# limpou preds
# 425
# 29 1
# limpou preds
# 426
# 34 1
# limpou preds
# 427
# 38 1
# limpou preds
# 428
# 43 1
# limpou preds
# 429
# 28 1
# limpou preds
# 430
# 49 1
# limpou preds
# 431
# 60 1
# limpou preds
# 432
# 8 1
# limpou preds
# 433
# 33 1
# limpou preds
# 434
# 9 1
# limpou preds
# 435
# 47 1
# limpou preds
# 436
# 93 1
# limpou preds
# 437
# 64 1
# limpou preds
# 438
# 34 1
# limpou preds
# 439
# 26 1
# limpou preds
# 440
# 22 1
# limpou preds
# 441
# 20 1
# limpou preds
# 442
# 30 1
# limpou preds
# 443
# 16 1
# limpou preds
# 444
# 18 1
# limpou preds
# 445
# 18 1
# limpou preds
# 446
# 38 1
# limpou preds
# 447
# 22 1
# limpou preds
# 448
# 25 1
# limpou preds
# 449
# 51 1
# limpou preds
# 450
# 25 1
# limpou preds
# 451
# 36 1
# limpou preds
# 452
# 34 1
# limpou preds
# 453
# 20 1
# limpou preds
# 454
# 50 1
# limpou preds
# 455
# 19 1
# limpou preds
# 456
# 20 1
# limpou preds
# 457
# 8 1
# limpou preds
# 458
# 45 1
# limpou preds
# 459
# 52 1
# limpou preds
# 460
# 226 1
# limpou preds
# 461
# 38 1
# limpou preds
# 462
# 19 1
# limpou preds
# 463
# 24 1
# limpou preds
# 464
# 43 1
# limpou preds
# 465
# 22 1
# limpou preds
# 466
# 44 1
# limpou preds
# 467
# 18 1
# limpou preds
# 468
# 12 1
# limpou preds
# 469
# 37 1
# limpou preds
# 470
# 20 1
# limpou preds
# 471
# 28 1
# limpou preds
# 472
# 49 1
# limpou preds
# 473
# 26 1
# limpou preds
# 474
# 24 1
# limpou preds
# 475
# 25 1
# limpou preds
# 476
# 24 1
# limpou preds
# 477
# 24 1
# limpou preds
# 478
# 19 1
# limpou preds
# 479
# 20 1
# limpou preds
# 480
# 15 1
# limpou preds
# 481
# 26 1
# limpou preds
# 482
# 37 1
# limpou preds
# 483
# 55 1
# limpou preds
# 484
# 43 1
# limpou preds
# 485
# 25 1
# limpou preds
# 486
# 19 1
# limpou preds
# 487
# 15 1
# limpou preds
# 488
# 46 1
# limpou preds
# 489
# 21 1
# limpou preds
# 490
# 26 1
# limpou preds
# 491
# 23 1
# limpou preds
# 492
# 45 1
# limpou preds
# 493
# 33 1
# limpou preds
# 494
# 33 1
# limpou preds
# 495
# 12 1
# limpou preds
# 496
# 23 1
# limpou preds
# 497
# 55 1
# limpou preds
# 498
# 24 1
# limpou preds
# 499

# %%
# precision_micro2 = []
# recall_micro2 = []
# f1_micro2 = []
# f1_macro2 = []
# precision_macro2 = []
# recall_macro2 = []
# f1_weighted2 = []
# precision_weighted2 = []
# recall_weighted2 = []
# accuracy2 = []
# name2 = []

# for keys,value in metrics_all2.items():
#     name2.append(keys)
#     precision_micro2.append(value['precision_micro'])
#     recall_micro2.append(value['recall_micro'])
#     f1_micro2.append(value['f1_micro'])
#     precision_macro2.append(value['precision_macro'])
#     recall_macro2.append(value['recall_macro'])
#     f1_macro2.append(value['f1_macro'])
#     precision_weighted2.append(value['precision_weighted'])
#     recall_weighted2.append(value['recall_weighted'])
#     f1_weighted2.append(value['f1_weighted'])
#     accuracy2.append(value['accuracy'])

# df_results2 = pd.DataFrame({'name':name2,
#                            'precision_micro':precision_micro2,
#                            'recall_micro':recall_micro2,
#                            'f1_micro':f1_micro2,
#                            'precision_macro':precision_macro2,
#                            'recall_macro':recall_macro2,
#                            'f1_macro':f1_macro2,
#                            'precision_weighted':precision_weighted2,
#                            'recall_weighted':recall_weighted2,
#                            'f1_weighted':f1_weighted2,
#                            'accuracy_score':accuracy2})

# %%
# df_results2.to_csv(f'metricas_{model_escolhido.replace(':', '')}_complemento.csv', index=False)

# %%
# df_results2
# Out:
# Empty DataFrame
# Columns: [name, precision_micro, recall_micro, f1_micro, precision_macro, recall_macro, f1_macro, precision_weighted, recall_weighted, f1_weighted, accuracy_score]
# Index: []
